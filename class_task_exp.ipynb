# %% [markdown]
# # Imports

# %%
from IPython.display import clear_output
import subprocess

subprocess.run(["pip", "freeze"], check=True)
clear_output(wait=False)

# %%
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)
import models
import matplotlib.pyplot as plt
import numpy as np
import torch
from fpdf import FPDF
import random
from datetime import datetime
import csv
from omegaconf import OmegaConf
import pyedflib
from scipy import signal, stats

import pandas as pd

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
import seaborn as sns

# %% [markdown]
# # Functions

# %%
# === Функции ===
def edf_extractor(file_name):
    f = pyedflib.EdfReader(file_name)
    n = f.signals_in_file
    signal_labels = f.getSignalLabels()
    sigbufs = np.zeros((n, f.getNSamples()[0]))
    for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)
    return sigbufs, signal_labels


def build_model(cfg):
    ckpt_path = cfg.upstream_ckpt
    init_state = init_state = torch.load(ckpt_path, weights_only=False)
    upstream_cfg = init_state["model_cfg"]
    upstream = models.build_model(upstream_cfg)
    return upstream


def load_model_weights(model, states, multi_gpu):
    if multi_gpu:
        model.module.load_weights(states)
    else:
        model.load_weights(states)


def initialize_model(ckpt_path: str):
    """
    Инициализация модели с заданным путем к контрольной точке (checkpoint).

    Args:
        ckpt_path (str): Путь к файлу контрольной точки.

    Returns:
        model: Инициализированная модель.
    """

    # Создание конфигурации и загрузка модели
    cfg = OmegaConf.create({"upstream_ckpt": ckpt_path})
    model = build_model(cfg)
    model.to("cuda")

    # Загрузка весов модели
    init_state = torch.load(ckpt_path, weights_only=False)
    load_model_weights(model, init_state["model"], False)

    return model


def create_save_dir(base_path: str) -> str:
    """Создаёт директорию с именем, основанным на текущей дате и времени."""
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    save_dir = os.path.join(base_path, timestamp)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir


def read_intervals_from_csv(file_path: str):
    """Читает интервалы из CSV-файла."""
    intervals = []
    activities = []
    with open(file_path, mode="r", encoding="utf-8") as csv_file:
        csv_reader = csv.reader(csv_file)
        for row in csv_reader:
            activities.append(row[0])
            intervals.append((float(row[1]), float(row[2])))
    return activities, intervals


def extract_intervals(original_file_path):
    """
    Преобразует оригинальный TSV файл в переменные для дальнейшей работы: activities, intervals и activity_type.

    Args:
        original_file_path (str): Путь к оригинальному TSV файлу.

    Returns:
        tuple: Три списка - activities, intervals и activity_type.
    """
    import pandas as pd

    # Чтение оригинального TSV файла
    df = pd.read_csv(original_file_path, sep="\t")

    # Извлечение необходимых столбцов
    required_columns = [
        "onset",
        "duration",
        "item_name",
        "trial_type",
        "test",
        "answer",
    ]
    if not all(col in df.columns for col in required_columns):
        raise ValueError(
            f"Оригинальный файл должен содержать столбцы: {required_columns}"
        )

    # Формирование интервалов, где конец интервала это onset следующего элемента
    onset_list = df["onset"].tolist() + [0]  # Добавляем 0 в конец
    intervals = [(onset_list[i], onset_list[i + 1]) for i in range(len(onset_list) - 1)]

    # Формирование activity_type
    activity_type = df["trial_type"].tolist()

    # Формирование activities с условием для PROB
    activities = [
        f"{test} = {answer}" if trial_type == "PROB" else item_name
        for test, answer, trial_type, item_name in zip(
            df["test"], df["answer"], df["trial_type"], df["item_name"]
        )
    ]

    return activities, intervals, activity_type


def get_model_outputs(stfts, model):
    # Форматирование тензоров и инференс модели
    inputs = torch.FloatTensor(np.stack(stfts)).transpose(1, 2).to("cuda")
    mask = torch.zeros((inputs.shape[:2])).bool().to("cuda")

    with torch.no_grad():
        out = model.forward(inputs, mask, intermediate_rep=True)
    return out

# %% [markdown]
# # Main launchers

# %%
class STFTProcessor:
    @staticmethod
    def baseline(data):
        # Пример реализации baseline (замените на свою, если требуется)
        return data - np.mean(data, axis=-1, keepdims=True)

    def __init__(self, fs, window_size, overlap, normalizing=None):
        """
        Инициализация процессора STFT.

        Параметры:
          fs : частота дискретизации.
          window_size : размер окна для STFT.
          overlap : количество отсчетов перекрытия.
          normalizing : тип нормализации ('zscore', 'baselined', 'db' или None).
        """
        self.fs = fs
        self.window_size = window_size
        self.overlap = overlap
        self.normalizing = normalizing
        # Эффективная длина – число отсчетов активной части, которые берутся из сигнала
        self.effective_length = window_size - overlap
        # Длина левого паддинга, чтобы итоговая длина стала window_size
        self.left_padding = self.window_size - self.effective_length
        # Порог для решения о дополнении: если длина интервала меньше threshold, то интервал отбрасывается и объединяется с последующим.
        self.threshold = self.effective_length // 2  # например, 50 -> 25

    def _padded_signal(self, segment):
        """
        Подготавливает активный участок:
          - Берутся первые effective_length отсчетов из segment (если их больше, иначе весь segment).
          - Слева добавляются нули для формирования полного окна.
        """
        padded_signal = np.pad(segment, (self.left_padding, 0), mode="constant")
        return padded_signal

    def _compute_stft(self, x):
        """
        Вычисляет STFT для подготовленного сигнала x с заданными параметрами.
        Применяется нормализация, если она указана.
        Возвращает:
          f : ось частот,
          t : временную ось,
          Zxx : матрицу STFT.
        """
        f, t, Zxx = signal.stft(
            x, self.fs, nperseg=self.window_size, noverlap=self.overlap
        )
        Zxx = np.abs(Zxx)
        clip = 5  # для устранения граничных эффектов
        if self.normalizing == "zscore":
            Zxx = Zxx[:, clip:-clip]
            Zxx = stats.zscore(Zxx, axis=-1)
            t = t[clip:-clip]
        elif self.normalizing == "baselined":
            Zxx = Zxx[:, clip:-clip]
            Zxx = self.baseline(Zxx)
            t = t[clip:-clip]
        elif self.normalizing == "db":
            Zxx = Zxx[:, clip:-clip]
            Zxx = np.log2(Zxx)
            t = t[clip:-clip]
        return f, t, Zxx

    def process_interval(self, segment, previous_t_offset=0):
        """
        Обрабатывает один активный интервал (зону активности).
          - Подготавливает сегмент (дополняя слева нулями до длины окна).
          - Вычисляет STFT.
          - Смещает временную ось на previous_t_offset.
          - Возвращает STFT, оси частот и времени, а также последнее значение времени.
        """
        padded_signal = self._prepare_signal(segment)
        f, t, Zxx = self._compute_stft(padded_signal)
        t = t + previous_t_offset
        last_t = t[-1] if len(t) > 0 else previous_t_offset
        return Zxx, f, t, last_t

    def process_trial(self, trial_signal, intervals, trial_start_time=None):
        """
        Обрабатывает весь трайал с учетом заданных интервалов активности и реализует логику объединения интервалов.

        Параметры:
          trial_signal : 1D массив, сигнал трайала, обрезанный по границам [trial_start, trial_end].
          intervals : список кортежей вида (label, (start, end)), где start и end заданы в секундах.
          trial_start_time : если задан, интервалы переводятся в относительные (относительно начала trial_signal).

        Логика объединения:
          - Интервалы переводятся в отсчеты.
          - Если длина интервала меньше effective_length:
               • если длина < threshold, то интервал отбрасывается из рассмотрения,
                 а левая граница следующего интервала сдвигается влево (принимая за начало текущего).
               • если длина между threshold и effective_length, то недостающая часть дополняется за счет начала следующего интервала,
                 а левая граница следующего интервала корректируется.
        Возвращает список кортежей: (label, Zxx, f, t, last_t) для каждого обработанного интервала.
        """
        results = []
        previous_t_offset = 0

        # Переводим интервалы из секунд в отсчеты
        intervals_samples = []
        for label, (start_sec, end_sec) in intervals:
            start_idx = int(start_sec * self.fs)
            end_idx = int(end_sec * self.fs)
            intervals_samples.append(
                {"label": label, "start": start_idx, "end": end_idx}
            )

        i = 0
        while i < len(intervals_samples):
            current = intervals_samples[i]
            current_length = current["end"] - current["start"]
            modulo = current_length % self.effective_length
            division = current_length // self.effective_length

            if modulo > self.threshold:
                # Интервал имеет длину между threshold и effective_length – пытаемся дополнить его за счет следующего интервала
                needed = self.effective_length - current_length
                next_interval = intervals_samples[i + 1]
                available = next_interval["end"] - next_interval["start"]
                if available >= needed:
                    # Дополняем сегмент:
                    segment_current = trial_signal[current["start"] : current["end"]]
                    segment_next = trial_signal[
                        next_interval["start"] : next_interval["start"] + needed
                    ]
                    segment = np.concatenate([segment_current, segment_next])
                    # Сдвигаем левую границу следующего интервала
                    next_interval["start"] += needed
                    Zxx, f, t, last_t = self.process_interval(
                        segment, previous_t_offset
                    )
                    results.append((current["label"], Zxx, f, t, last_t))
                    previous_t_offset = last_t
                else:
                    # Если следующего интервала недостаточно, объединяем текущий с следующим:
                    next_interval["start"] = current["start"]
            elif modulo > 0:
                # Если интервал слишком короткий (< threshold), отбрасываем его и объединяем с следующим
                # (если следующий есть, иначе пропустить операцию):
                if i + 1 < len(intervals_samples):
                    # Сдвигаем левую границу следующего интервала влево до начала текущего
                    intervals_samples[i + 1]["start"] = (
                        intervals_samples[i + 1]["start"] - modulo
                    )
                    current["end"] = intervals_samples[i + 1]["start"] - modulo - 1

            # Если интервал достаточной длины, берем первые effective_length отсчетов
            segment = trial_signal[
                current["start"] : current["start"] + self.effective_length
            ]
            Zxx, f, t, last_t = self.process_interval(segment, previous_t_offset)
            results.append((current["label"], Zxx, f, t, last_t))
            previous_t_offset = last_t
            i += 1

        return results

# %%
# === Параметры ===
# Пути к данным и моделям
ckpt_path = "/trinity/home/asma.benachour/BERT_init_weights/stft_large_pretrained.pth"
path_to = "/trinity/home/asma.benachour/Haydn Free recall/sub-R1001P/ses-0/ieeg/"
# csv_file_path = "/beegfs/home/g.soghoyan/George/BERT-intervals/first_intervalR1001P.csv"
tsv_file_path = "/trinity/home/asma.benachour/Haydn Free recall/sub-R1001P/ses-0/ieeg/sub-R1001P_ses-0_task-FR1_events.tsv"
pdf_output_dir = "/trinity/home/asma.benachour/PDF/"

os.makedirs(pdf_output_dir, exist_ok=True)

# %%
# Инициализация модели
model = initialize_model(ckpt_path)
# Out:
# /home/asma.benachour/miniconda3/envs/brainbert/lib/python3.10/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
# Создание директории для сохранения
save_dir = create_save_dir(pdf_output_dir)

# %%
path_to = "/trinity/home/asma.benachour/Haydn Free recall/sub-R1001P/ses-0/ieeg/"
left_suff = "sub-R1001P_ses-0_task-FR1_acq-"
right_suff = "_ieeg.edf"
signal_types = ["monopolar", "bipolar"]
file_name = {}
recording = {}
signal_labels = {}
for s_type in signal_types:
    file_name[s_type] = f"{path_to}{left_suff}{s_type}{right_suff}"
    recording[s_type], signal_labels[s_type] = edf_extractor(file_name[s_type])
SamplingFrequency = 500
chosen_rec = "bipolar"
framecap = 50000

# %%
def universal_label_and_merge(group, search_col, mapping, default_label="OTHER"):
    """
    Универсальная функция для разметки и объединения интервалов в рамках одного трайала.

    Аргументы:
        group (pd.DataFrame): Датафрейм с событиями одного трайала.
                              Обязательно должен содержать столбцы "onset" и "duration".
        search_col (str): Имя столбца, по которому производится сопоставление (например, "trial_type").
        mapping (dict): Словарь вида {new_label (str): set(исходных меток)}.
        default_label (str): Ярлык для событий, не попавших ни в одну группу из mapping.

    Возвращает:
        pd.DataFrame с колонками ["label", "start", "end"].
    """
    # 1. Сортировка по времени
    group_sorted = (
        group.loc[:, ["onset", "duration", search_col]]
        .sort_values("onset")
        .reset_index(drop=True)
    )

    # 2. Корректировка столбца "duration"
    ind = group_sorted.columns.get_loc("duration")
    dur = group_sorted.iloc[-1, ind]
    group_sorted["duration"] = (
        group_sorted["onset"].diff(periods=-1).apply(lambda x: x * -1)
    )
    group_sorted.iloc[-1, ind] = dur

    # 3. Присваиваем новый ярлык каждому событию
    reverse_mapping = {
        orig_label: new_label
        for new_label, orig_labels in mapping.items()
        for orig_label in orig_labels
    }
    group_sorted["label"] = (
        group_sorted[search_col].map(reverse_mapping).fillna(default_label)
    )

    # 4. Вычисление конечных точек (start, end)
    group_sorted["end"] = group_sorted["onset"] + group_sorted["duration"]

    # 5. Группировка подряд идущих событий с одинаковым `label`
    group_sorted["group"] = (
        group_sorted["label"] != group_sorted["label"].shift()
    ).cumsum()

    merged_df = group_sorted.groupby("group", as_index=False).agg(
        label=("label", "first"), start=("onset", "first"), end=("end", "last")
    )

    return merged_df[["label", "start", "end"]]

# %%
# 1. Загрузка поведенческого документа.
# Предполагается, что файл имеет разделитель табуляция, если другой – измените sep.
behavior_df = pd.read_csv(tsv_file_path, sep="\t")
df = behavior_df
# 2. Фильтрация строк с маркером начала трайала.
# Здесь предполагается, что начало трайала отмечено в столбце "trial_type" значением "TRIAL".
trial_df = behavior_df[behavior_df["trial_type"] == "TRIAL"].reset_index(drop=True)

# 3. Исключаем первый трайал, если требуется (например, он может быть служебным).
trial_df = trial_df.iloc[1:]  # Если нужно исключить первый трайал

# 4. Создаем интервалы: для каждой строки берем время начала текущего трайала и время начала следующего.
trial_df["next_onset"] = trial_df["onset"].shift(-1)
# Убираем последнюю строку, у которой нет следующего onset (т.е. не образует интервал)
trial_df = trial_df.dropna(subset=["next_onset"])

# Преобразуем интервалы в список пар (start, end)
trials = trial_df[["onset", "next_onset"]].values.tolist()
print("Извлечённые интервалы трайалов:", trials)
# Out:
# Извлечённые интервалы трайалов: [[308.201, 407.853], [407.853, 507.522], [507.522, 615.209], [615.209, 711.377], [711.377, 1071.861], [1071.861, 1184.266], [1184.266, 1308.922], [1308.922, 1420.81], [1420.81, 1533.248], [1533.248, 1646.853], [1646.853, 1759.907], [1759.907, 1873.912], [1873.912, 1974.314], [1974.314, 2079.917], [2079.917, 2569.459], [2569.459, 2669.645], [2669.645, 2774.398], [2774.398, 2878.034], [2878.034, 2997.34], [2997.34, 3113.845], [3113.845, 3221.466], [3221.466, 3327.852], [3327.852, 3433.139]]

# %%
df_trials = df[df["list"] > 0].copy()
df_trials.sort_values("onset", inplace=True)

results = []
# Пример словаря: для COUNTDOWN объединяем "COUNTDOWN_START" и "TRIAL", для WORD – "WORD", для PROB – "PROB", для REC_WORD – "REC_WORD"
mapping = {
    "COUNTDOWN": {"COUNTDOWN_START", "TRIAL", "COUNTDOWN_STOP", "COUNTDOWN_END"},
    "WORD": {"WORD"},
    "PROB": {"PROB"},
    "REC_WORD": {"REC_WORD"},
}

for trial_id, group in df_trials.groupby("list"):
    intervals = universal_label_and_merge(
        group, search_col="trial_type", mapping=mapping, default_label="OTHER"
    )
    results.append(intervals)

# %%
results
# Out:
# [       label    start      end
#  0  COUNTDOWN  200.214  210.649
#  1      OTHER  210.649  213.233
#  2       WORD  213.233  242.522
#  3      OTHER  242.522  242.539
#  4       PROB  242.539  268.729
#  5      OTHER  268.729  308.201,
#         label    start      end
#  0  COUNTDOWN  308.201  318.636
#  1      OTHER  318.636  321.087
#  2       WORD  321.087  350.376
#  3      OTHER  350.376  350.392
#  4       PROB  350.392  373.802
#  5      OTHER  373.802  379.302
#  6   REC_WORD  379.302  383.901
#  7      OTHER  383.901  397.586
#  8   REC_WORD  397.586  405.042
#  9      OTHER  405.042  407.853,
#         label    start      end
#  0  COUNTDOWN  407.853  418.288
#  1      OTHER  418.288  420.906
#  2       WORD  420.906  450.411
#  3      OTHER  450.411  450.428
#  4       PROB  450.428  470.562
#  5      OTHER  470.562  473.550
#  6   REC_WORD  473.550  486.268
#  7      OTHER  486.268  488.046
#  8   REC_WORD  488.046  501.643
#  9      OTHER  501.643  507.522,
#         label    start      end
#  0  COUNTDOWN  507.522  517.957
#  1      OTHER  517.957  520.458
#  2       WORD  520.458  549.563
#  3      OTHER  549.563  549.580
#  4       PROB  549.580  572.162
#  5      OTHER  572.162  576.956
#  6   REC_WORD  576.956  586.992
#  7      OTHER  586.992  587.403
#  8   REC_WORD  587.403  603.395
#  9      OTHER  603.395  615.209,
#         label    start      end
#  0  COUNTDOWN  615.209  625.644
#  1      OTHER  625.644  628.094
#  2       WORD  628.094  656.916
#  3      OTHER  656.916  656.933
#  4       PROB  656.933  677.154
#  5      OTHER  677.154  711.377,
#         label    start       end
#  0  COUNTDOWN  711.377   721.812
#  1      OTHER  721.812   724.196
#  2       WORD  724.196   753.035
#  3      OTHER  753.035   753.051
#  4       PROB  753.051   781.362
#  5      OTHER  781.362  1071.861,
#         label     start       end
#  0  COUNTDOWN  1071.861  1082.296
#  1      OTHER  1082.296  1084.880
#  2       WORD  1084.880  1114.119
#  3      OTHER  1114.119  1114.136
#  4       PROB  1114.136  1145.098
#  5      OTHER  1145.098  1157.757
#  6   REC_WORD  1157.757  1176.270
#  7      OTHER  1176.270  1184.266,
#         label     start       end
#  0  COUNTDOWN  1184.266  1194.700
#  1      OTHER  1194.700  1197.201
#  2       WORD  1197.201  1226.007
#  3      OTHER  1226.007  1226.023
#  4       PROB  1226.023  1263.298
#  5      OTHER  1263.298  1278.369
#  6   REC_WORD  1278.369  1294.496
#  7      OTHER  1294.496  1308.922,
#         label     start       end
#  0  COUNTDOWN  1308.922  1319.358
#  1      OTHER  1319.358  1321.908
#  2       WORD  1321.908  1351.014
#  3      OTHER  1351.014  1351.030
#  4       PROB  1351.030  1376.218
#  5      OTHER  1376.218  1380.949
#  6   REC_WORD  1380.949  1407.446
#  7      OTHER  1407.446  1420.810,
#         label     start       end
#  0  COUNTDOWN  1420.810  1431.245
#  1      OTHER  1431.245  1433.661
#  2       WORD  1433.661  1462.717
#  3      OTHER  1462.717  1462.734
#  4       PROB  1462.734  1491.737
#  5      OTHER  1491.737  1497.512
#  6   REC_WORD  1497.512  1507.373
#  7      OTHER  1507.373  1507.877
#  8   REC_WORD  1507.877  1515.247
#  9      OTHER  1515.247  1533.248,
#         label     start       end
#  0  COUNTDOWN  1533.248  1543.682
#  1      OTHER  1543.682  1546.084
#  2       WORD  1546.084  1575.106
#  3      OTHER  1575.106  1575.122
#  4       PROB  1575.122  1600.673
#  5      OTHER  1600.673  1604.979
#  6   REC_WORD  1604.979  1609.133
#  7      OTHER  1609.133  1624.586
#  8   REC_WORD  1624.586  1631.855
#  9      OTHER  1631.855  1646.853,
#         label     start       end
#  0  COUNTDOWN  1646.853  1657.288
#  1      OTHER  1657.288  1659.671
#  2       WORD  1659.671  1688.894
#  3      OTHER  1688.894  1688.910
#  4       PROB  1688.910  1713.602
#  5      OTHER  1713.602  1718.296
#  6   REC_WORD  1718.296  1732.828
#  7      OTHER  1732.828  1733.434
#  8   REC_WORD  1733.434  1744.663
#  9      OTHER  1744.663  1759.907,
#         label     start       end
#  0  COUNTDOWN  1759.907  1770.342
#  1      OTHER  1770.342  1772.810
#  2       WORD  1772.810  1802.082
#  3      OTHER  1802.082  1802.098
#  4       PROB  1802.098  1832.098
#  5      OTHER  1832.098  1836.656
#  6   REC_WORD  1836.656  1863.300
#  7      OTHER  1863.300  1873.912,
#         label     start       end
#  0  COUNTDOWN  1873.912  1884.347
#  1      OTHER  1884.347  1886.831
#  2       WORD  1886.831  1915.903
#  3      OTHER  1915.903  1915.920
#  4       PROB  1915.920  1937.458
#  5      OTHER  1937.458  1940.735
#  6   REC_WORD  1940.735  1965.525
#  7      OTHER  1965.525  1974.314,
#         label     start       end
#  0  COUNTDOWN  1974.314  1984.749
#  1      OTHER  1984.749  1987.300
#  2       WORD  1987.300  2016.072
#  3      OTHER  2016.072  2016.089
#  4       PROB  2016.089  2042.018
#  5      OTHER  2042.018  2045.990
#  6   REC_WORD  2045.990  2068.632
#  7      OTHER  2068.632  2079.917,
#         label     start       end
#  0  COUNTDOWN  2079.917  2090.353
#  1      OTHER  2090.353  2092.870
#  2       WORD  2092.870  2122.442
#  3      OTHER  2122.442  2122.459
#  4       PROB  2122.459  2142.450
#  5      OTHER  2142.450  2145.376
#  6   REC_WORD  2145.376  2161.231
#  7      OTHER  2161.231  2569.459,
#         label     start       end
#  0  COUNTDOWN  2569.459  2579.895
#  1      OTHER  2579.895  2582.345
#  2       WORD  2582.345  2611.716
#  3      OTHER  2611.716  2611.733
#  4       PROB  2611.733  2634.242
#  5      OTHER  2634.242  2637.597
#  6   REC_WORD  2637.597  2645.294
#  7      OTHER  2645.294  2669.645,
#         label     start       end
#  0  COUNTDOWN  2669.645  2680.080
#  1      OTHER  2680.080  2682.696
#  2       WORD  2682.696  2711.786
#  3      OTHER  2711.786  2711.803
#  4       PROB  2711.803  2736.554
#  5      OTHER  2736.554  2740.135
#  6   REC_WORD  2740.135  2767.606
#  7      OTHER  2767.606  2774.398,
#         label     start       end
#  0  COUNTDOWN  2774.398  2784.833
#  1      OTHER  2784.833  2787.284
#  2       WORD  2787.284  2816.472
#  3      OTHER  2816.472  2816.489
#  4       PROB  2816.489  2840.370
#  5      OTHER  2840.370  2844.765
#  6   REC_WORD  2844.765  2871.439
#  7      OTHER  2871.439  2878.034,
#          label     start       end
#  0   COUNTDOWN  2878.034  2888.469
#  1       OTHER  2888.469  2890.986
#  2        WORD  2890.986  2920.108
#  3       OTHER  2920.108  2920.125
#  4        PROB  2920.125  2949.418
#  5       OTHER  2949.418  2954.089
#  6    REC_WORD  2954.089  2964.121
#  7       OTHER  2964.121  2964.752
#  8    REC_WORD  2964.752  2973.741
#  9       OTHER  2973.741  2974.036
#  10   REC_WORD  2974.036  2976.095
#  11      OTHER  2976.095  2997.340,
#         label     start       end
#  0  COUNTDOWN  2997.340  3007.775
#  1      OTHER  3007.775  3010.192
#  2       WORD  3010.192  3038.998
#  3      OTHER  3038.998  3039.014
#  4       PROB  3039.014  3070.906
#  5      OTHER  3070.906  3075.962
#  6   REC_WORD  3075.962  3092.288
#  7      OTHER  3092.288  3098.298
#  8   REC_WORD  3098.298  3102.118
#  9      OTHER  3102.118  3113.845,
#         label     start       end
#  0  COUNTDOWN  3113.845  3124.280
#  1      OTHER  3124.280  3126.679
#  2       WORD  3126.679  3155.719
#  3      OTHER  3155.719  3155.735
#  4       PROB  3155.735  3180.290
#  5      OTHER  3180.290  3183.284
#  6   REC_WORD  3183.284  3203.802
#  7      OTHER  3203.802  3221.465,
#         label     start       end
#  0  COUNTDOWN  3221.465  3231.900
#  1      OTHER  3231.900  3234.284
#  2       WORD  3234.284  3263.739
#  3      OTHER  3263.739  3263.756
#  4       PROB  3263.756  3287.410
#  5      OTHER  3287.410  3290.687
#  6   REC_WORD  3290.687  3299.825
#  7      OTHER  3299.825  3300.212
#  8   REC_WORD  3300.212  3318.604
#  9      OTHER  3318.604  3327.852,
#         label     start       end
#  0  COUNTDOWN  3327.852  3338.287
#  1      OTHER  3338.287  3340.788
#  2       WORD  3340.788  3369.976
#  3      OTHER  3369.976  3369.993
#  4       PROB  3369.993  3395.810
#  5      OTHER  3395.810  3401.857
#  6   REC_WORD  3401.857  3427.010
#  7      OTHER  3427.010  3433.138,
#         label     start       end
#  0  COUNTDOWN  3433.138  3443.574
#  1      OTHER  3443.574  3446.141
#  2       WORD  3446.141  3475.146
#  3      OTHER  3475.146  3475.163
#  4       PROB  3475.163  3500.642
#  5      OTHER  3500.642  3505.958
#  6   REC_WORD  3505.958  3528.261
#  7      OTHER  3528.261  3575.032]

# %%
import numpy as np
import pandas as pd
from scipy import signal, stats
from typing import List, Tuple, Dict, Optional


class STFTProcessor:
    """
    Класс для обработки сигналов с использованием STFT (Кратковременное преобразование Фурье).

    Функционал:
    - Преобразует интервалы из секунд в дискретные отсчёты.
    - Корректирует интервалы, устраняя артефакты округления.
    - Объединяет или дополняет короткие интервалы.
    - Выполняет STFT на обработанных интервалах с возможностью нормализации.
    """

    @staticmethod
    def baseline(data: np.ndarray) -> np.ndarray:
        """Вычисляет базовую линию, вычитая среднее значение по оси."""
        return data - np.mean(data, axis=-1, keepdims=True)

    def __init__(
        self,
        fs: int,
        window_size: int,
        overlap: int,
        normalizing: Optional[str] = None,
        debug: bool = False,
    ):
        """
        Инициализация класса STFTProcessor.

        :param fs: Частота дискретизации (Гц)
        :param window_size: Размер окна для STFT
        :param overlap: Количество перекрывающихся отсчётов
        :param normalizing: Способ нормализации ('zscore', 'baselined', 'db' или None)
        :param debug: Флаг для вывода отладочной информации
        """
        self.fs = fs
        self.window_size = window_size
        self.overlap = overlap
        self.normalizing = normalizing
        self.debug = debug
        self.effective_length = window_size - overlap
        self.left_padding = window_size - self.effective_length
        self.threshold = self.effective_length // 2
        if self.debug:
            print(
                "Initialized STFTProcessor with fs:",
                fs,
                "window_size:",
                window_size,
                "overlap:",
                overlap,
                "effective_length:",
                self.effective_length,
            )

    def _convert_intervals_to_samples(
        self, intervals_df: pd.DataFrame
    ) -> List[Dict[str, int]]:
        """
        Преобразует интервалы из секунд в отсчёты.

        :param intervals_df: DataFrame с колонками ["label", "start", "end"] в секундах
        :return: Список интервалов в отсчётах
        """
        intervals_df = intervals_df.copy()
        # Преобразование секунд в отсчёты
        intervals_df["start"] = (intervals_df["start"] * self.fs).round().astype(int)
        intervals_df["end"] = (intervals_df["end"] * self.fs).round().astype(
            int
        ) - 1  # Вычитание 1 для соответствия индексам

        if self.debug:
            print("Converted intervals to samples:")
            print(intervals_df)

        return intervals_df.to_dict(orient="records")

    def _merge_or_extend_intervals(
        self, intervals_samples: List[Dict[str, int]]
    ) -> List[Dict[str, int]]:
        """
        Объединяет или дополняет короткие интервалы, чтобы избежать пропусков.

        :param intervals_samples: Список интервалов в отсчётах
        :return: Обновленный список интервалов
        """
        i = 0
        processed_intervals = []
        if self.debug:
            print("Original intervals_samples:", intervals_samples)
        while i < len(intervals_samples):
            current = intervals_samples[i]
            current_length = current["end"] - current["start"]
            modulo = current_length % self.effective_length
            division = current_length // self.effective_length
            if self.debug:
                print(
                    f"Processing interval {i}: start={current['start']}, end={current['end']}, "
                    f"length={current_length}, modulo={modulo}, division={division}"
                )

            if modulo > self.threshold:
                if i + 1 < len(intervals_samples):
                    next_interval = intervals_samples[i + 1]
                    needed = self.effective_length - modulo
                    available = next_interval["end"] - next_interval["start"]
                    if self.debug:
                        print(
                            f"Interval {i} modulo > threshold, needed={needed}, next interval available={available}"
                        )
                    if available >= needed:
                        next_interval["start"] += needed + 1
                        current["end"] += needed
                        if self.debug:
                            print(
                                f"Extended interval {i} by {needed} samples, new end: {current['end']}, "
                                f"next interval new start: {next_interval['start']}"
                            )
                    else:
                        combined_end = intervals_samples.pop(i + 1)["end"]
                        current["end"] = combined_end
                        if self.debug:
                            print(
                                f"Merged interval {i} with next interval, new end: {current['end']}"
                            )
                        continue
                processed_intervals.append(current)
            elif modulo > 0 and division > 0:
                if i + 1 < len(intervals_samples):
                    next_interval = intervals_samples[i + 1]
                    next_interval["start"] -= modulo
                    current["end"] = next_interval["start"] - 1
                    if self.debug:
                        print(
                            f"Adjusted interval {i} with modulo {modulo}, new end: {current['end']}, "
                            f"next interval new start: {next_interval['start']}"
                        )
                processed_intervals.append(current)
            else:
                if self.debug:
                    print(f"Discarding interval {i} as it has no valid length")
                intervals_samples.pop(i)
                continue
            i += 1
        if self.debug:
            print("Processed intervals_samples:", processed_intervals)
        return processed_intervals

    def process_trial(
        self, trial_signal: np.ndarray, intervals: pd.DataFrame
    ) -> List[Tuple[str, np.ndarray, np.ndarray, np.ndarray, float]]:
        """
        Обрабатывает трайал, вычисляя STFT для заданных интервалов,
        и возвращает единую структуру с матрицей STFT и соответствующими метками.

        Возвращает словарь с ключами:
        - 't': 1D numpy массив временных меток для всех бинов
        - 'f': 1D numpy массив частотной сетки
        - 'Zxx': 2D numpy массив STFT-коэффициентов (shape = (n_f, n_time_bins))
        - 'labels': 1D numpy массив меток активности для каждого временного бина
        """
        t_all = []
        labels_all = []
        Zxx_list = []
        f_global = None

        # Преобразуем интервалы и объединяем их
        intervals_samples = self._convert_intervals_to_samples(intervals)
        intervals_samples = self._merge_or_extend_intervals(intervals_samples)

        for interval in intervals_samples:
            segment = trial_signal[interval["start"] : interval["end"]]
            t_offset = interval["start"] / self.fs
            Zxx, f, t, _ = self.process_interval(segment, t_offset)
            if f_global is None:
                f_global = (
                    f  # частотная сетка должна быть одинаковой во всех интервалах
                )
            t_all.append(t)
            labels_all.extend([interval["label"]] * len(t))
            Zxx_list.append(Zxx)  # Zxx имеет форму (n_f, n_t_interval)

        # Объединяем данные по времени
        t_all = np.concatenate(t_all)  # shape = (n_total_time_bins,)
        Zxx_all = np.hstack(Zxx_list)  # shape = (n_f, n_total_time_bins)
        labels_all = np.array(labels_all)

        return {"t": t_all, "f": f_global, "Zxx": Zxx_all, "labels": labels_all}

    def process_interval(
        self, segment: np.ndarray, t_offset: float = 0
    ) -> Tuple[np.ndarray, np.ndarray, np.ndarray, float]:
        """
        Обрабатывает отдельный интервал сигнала.

        :param segment: Сегмент сигнала
        :param t_offset: Абсолютное смещение времени (в секундах)
        :return: (Zxx, f, t, последнее значение t)
        """
        if self.debug:
            print(
                f"Processing segment of length {len(segment)} with t_offset={t_offset:.4f}"
            )

        padded_signal = self._prepare_signal(segment)

        f, t, Zxx = self._compute_stft(padded_signal)

        # Используем абсолютное смещение вместо накопительного previous_t_offset
        t += t_offset

        last_t = t[-1] if len(t) > 0 else t_offset
        if self.debug:
            print(
                f"Interval processed: new t[0]={t[0] if len(t) > 0 else 'N/A'}, last_t={last_t:.4f}"
            )

        return Zxx, f, t, last_t

    def _prepare_signal(self, segment: np.ndarray) -> np.ndarray:
        """
        Дополняет сигнал нулями для корректного разбиения окна.

        :param segment: Одномерный массив сигнала
        :return: Дополненный сигнал
        """
        if self.debug:
            print("Preparing signal segment, original length:", len(segment))
        padded_signal = np.pad(segment, (self.left_padding, 0), mode="constant")
        if self.debug:
            print("Signal segment length after padding:", len(padded_signal))
        return padded_signal

    def _compute_stft(self, x: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
        """
        Вычисляет STFT и применяет нормализацию.

        :param x: Одномерный массив сигнала
        :return: Частотная ось, временная ось, STFT-коэффициенты
        """
        f, t, Zxx = signal.stft(
            x,
            self.fs,
            nperseg=self.window_size,
            noverlap=self.overlap,
            boundary=None,
            padded=True,
        )
        if self.debug:
            print(
                "STFT raw output: len(f) =",
                len(f),
                "len(t) =",
                len(t),
                "Zxx shape =",
                Zxx.shape,
            )
        Zxx = np.abs(Zxx)
        clip = 5
        if self.normalizing == "zscore":
            Zxx = Zxx[:, clip:-clip]
            Zxx = stats.zscore(Zxx, axis=-1)
            t = t[clip:-clip]
        elif self.normalizing == "baselined":
            Zxx = Zxx[:, clip:-clip]
            Zxx = self.baseline(Zxx)
            t = t[clip:-clip]
        elif self.normalizing == "db":
            Zxx = Zxx[:, clip:-clip]
            Zxx = np.log2(Zxx)
            t = t[clip:-clip]
        if self.debug:
            print("STFT after normalization: len(t) =", len(t))
        return f, t, Zxx

# %%
SFTP = STFTProcessor(fs=500, window_size=150, overlap=50, debug=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 SFTP = STFTProcessor(fs = 500, window_size = 150, overlap = 50, debug = False)
#
# NameError: name 'STFTProcessor' is not defined

# %%
# recording[референс][канал][round(trials[номер][начало]*частота): round(trials[номер][конец]*частота) - 1].shape
trial_lft_bnd = round(trials[0][0] * 500)
trial_rgt_bnd = round(trials[0][-1] * 500) - 1
channel = 0
recording[chosen_rec][channel][trial_lft_bnd:trial_rgt_bnd].shape
# signal_labels["bipolar"]
# Out:
# (49825,)

# %%
trial_signal = recording[chosen_rec][channel]
intervals = results[15]

# %%
intervals
# Out:
#        label     start       end
# 0  COUNTDOWN  2079.917  2090.353
# 1      OTHER  2090.353  2092.870
# 2       WORD  2092.870  2122.442
# 3      OTHER  2122.442  2122.459
# 4       PROB  2122.459  2142.450
# 5      OTHER  2142.450  2145.376
# 6   REC_WORD  2145.376  2161.231
# 7      OTHER  2161.231  2569.459

# %%
intervals.iloc[-1, 2] - intervals.iloc[0, 1]
# Out:
# 489.5419999999999

# %%
sftp_trial = SFTP.process_trial(trial_signal, intervals)

# %%
sftp_trial["t"].shape
# Out:
# (2448,)

# %%
sftp_trial["f"].shape
# Out:
# (76,)

# %%
sftp_trial["labels"].shape
# Out:
# (2448,)

# %%
sftp_trial["Zxx"].shape
# Out:
# (76, 2448)

# %%
sftp_trial[-1][-1]
# Out:
# 2569.534

# %%
(sftp_trial[-1][-1] * 500 - 10 * 100) / 500
# Out:
# 2567.534

# %%
itr.iloc[-1, 2]
# Out:
# 3575.032

# %%
itr.iloc[0, 1]
# Out:
# 3433.138

# %%
summ = 0.0
for i, itr in enumerate(results):
    sftp_trial = SFTP.process_trial(trial_signal, itr)
    # difference = itr.iloc[-1,2] - itr.iloc[0,1] - sftp_trial[-1][-1]
    difference = itr.iloc[-1, 2] - sftp_trial[-1][-1]
    summ += difference
    print(f"{i},{difference}")
print(
    f"итого: {summ} из {results[-1].iloc[-1,2] - results[0].iloc[0,1]} секунд исходной записи."
)
# Out:
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  100107  105323
# 1      OTHER  105324  106615
# 2       WORD  106616  121260
# 3      OTHER  121261  121269
# 4       PROB  121270  134363
# 5      OTHER  134364  154099
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 100107, 'end': 105323}, {'label': 'OTHER', 'start': 105324, 'end': 106615}, {'label': 'WORD', 'start': 106616, 'end': 121260}, {'label': 'OTHER', 'start': 121261, 'end': 121269}, {'label': 'PROB', 'start': 121270, 'end': 134363}, {'label': 'OTHER', 'start': 134364, 'end': 154099}]
# Processing interval 0: start=100107, end=105323, length=5216, modulo=16, division=52
# Adjusted interval 0 with modulo 16, new end: 105307, next interval new start: 105308
# Processing interval 1: start=105308, end=106615, length=1307, modulo=7, division=13
# Adjusted interval 1 with modulo 7, new end: 106608, next interval new start: 106609
# Processing interval 2: start=106609, end=121260, length=14651, modulo=51, division=146
# Interval 2 modulo > threshold, needed=49, next interval available=8
# Merged interval 2 with next interval, new end: 121269
# Processing interval 2: start=106609, end=121269, length=14660, modulo=60, division=146
# Interval 2 modulo > threshold, needed=40, next interval available=13093
# Extended interval 2 by 40 samples, new end: 121309, next interval new start: 121311
# Processing interval 3: start=121311, end=134363, length=13052, modulo=52, division=130
# Interval 3 modulo > threshold, needed=48, next interval available=19735
# Extended interval 3 by 48 samples, new end: 134411, next interval new start: 134413
# Processing interval 4: start=134413, end=154099, length=19686, modulo=86, division=196
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 100107, 'end': 105307}, {'label': 'OTHER', 'start': 105308, 'end': 106608}, {'label': 'WORD', 'start': 106609, 'end': 121309}, {'label': 'PROB', 'start': 121311, 'end': 134411}, {'label': 'OTHER', 'start': 134413, 'end': 154099}]
# Processing interval 0: start=100107, end=105307, segment length=5200, t_offset=200.2140
# Processing segment of length 5200 with t_offset=200.2140
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=200.364, last_t=210.5640
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=105308, end=106608, segment length=1300, t_offset=210.6160
# Processing segment of length 1300 with t_offset=210.6160
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=210.76600000000002, last_t=213.1660
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=106609, end=121309, segment length=14700, t_offset=213.2180
# Processing segment of length 14700 with t_offset=213.2180
# Preparing signal segment, original length: 14700
# Signal segment length after padding: 14750
# STFT raw output: len(f) = 76 len(t) = 147 Zxx shape = (76, 147)
# STFT after normalization: len(t) = 147
# Interval processed: new t[0]=213.368, last_t=242.5680
# Interval 2: expected bins=147.0, actual bins=147, diff=0.0
# Processing interval 3: start=121311, end=134411, segment length=13100, t_offset=242.6220
# Processing segment of length 13100 with t_offset=242.6220
# Preparing signal segment, original length: 13100
# Signal segment length after padding: 13150
# STFT raw output: len(f) = 76 len(t) = 131 Zxx shape = (76, 131)
# STFT after normalization: len(t) = 131
# Interval processed: new t[0]=242.77200000000002, last_t=268.7720
# Interval 3: expected bins=131.0, actual bins=131, diff=0.0
# Processing interval 4: start=134413, end=154099, segment length=19686, t_offset=268.8260
# Processing segment of length 19686 with t_offset=268.8260
# Preparing signal segment, original length: 19686
# Signal segment length after padding: 19736
# STFT raw output: len(f) = 76 len(t) = 197 Zxx shape = (76, 197)
# STFT after normalization: len(t) = 197
# Interval processed: new t[0]=268.976, last_t=308.1760
# Interval 4: expected bins=196.86, actual bins=197, diff=0.13999999999998636
# 0,0.024999999999977263
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  154100  159317
# 1      OTHER  159318  160543
# 2       WORD  160544  175187
# 3      OTHER  175188  175195
# 4       PROB  175196  186900
# 5      OTHER  186901  189650
# 6   REC_WORD  189651  191949
# 7      OTHER  191950  198792
# 8   REC_WORD  198793  202520
# 9      OTHER  202521  203925
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 154100, 'end': 159317}, {'label': 'OTHER', 'start': 159318, 'end': 160543}, {'label': 'WORD', 'start': 160544, 'end': 175187}, {'label': 'OTHER', 'start': 175188, 'end': 175195}, {'label': 'PROB', 'start': 175196, 'end': 186900}, {'label': 'OTHER', 'start': 186901, 'end': 189650}, {'label': 'REC_WORD', 'start': 189651, 'end': 191949}, {'label': 'OTHER', 'start': 191950, 'end': 198792}, {'label': 'REC_WORD', 'start': 198793, 'end': 202520}, {'label': 'OTHER', 'start': 202521, 'end': 203925}]
# Processing interval 0: start=154100, end=159317, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 159300, next interval new start: 159301
# Processing interval 1: start=159301, end=160543, length=1242, modulo=42, division=12
# Adjusted interval 1 with modulo 42, new end: 160501, next interval new start: 160502
# Processing interval 2: start=160502, end=175187, length=14685, modulo=85, division=146
# Interval 2 modulo > threshold, needed=15, next interval available=7
# Merged interval 2 with next interval, new end: 175195
# Processing interval 2: start=160502, end=175195, length=14693, modulo=93, division=146
# Interval 2 modulo > threshold, needed=7, next interval available=11704
# Extended interval 2 by 7 samples, new end: 175202, next interval new start: 175204
# Processing interval 3: start=175204, end=186900, length=11696, modulo=96, division=116
# Interval 3 modulo > threshold, needed=4, next interval available=2749
# Extended interval 3 by 4 samples, new end: 186904, next interval new start: 186906
# Processing interval 4: start=186906, end=189650, length=2744, modulo=44, division=27
# Adjusted interval 4 with modulo 44, new end: 189606, next interval new start: 189607
# Processing interval 5: start=189607, end=191949, length=2342, modulo=42, division=23
# Adjusted interval 5 with modulo 42, new end: 191907, next interval new start: 191908
# Processing interval 6: start=191908, end=198792, length=6884, modulo=84, division=68
# Interval 6 modulo > threshold, needed=16, next interval available=3727
# Extended interval 6 by 16 samples, new end: 198808, next interval new start: 198810
# Processing interval 7: start=198810, end=202520, length=3710, modulo=10, division=37
# Adjusted interval 7 with modulo 10, new end: 202510, next interval new start: 202511
# Processing interval 8: start=202511, end=203925, length=1414, modulo=14, division=14
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 154100, 'end': 159300}, {'label': 'OTHER', 'start': 159301, 'end': 160501}, {'label': 'WORD', 'start': 160502, 'end': 175202}, {'label': 'PROB', 'start': 175204, 'end': 186904}, {'label': 'OTHER', 'start': 186906, 'end': 189606}, {'label': 'REC_WORD', 'start': 189607, 'end': 191907}, {'label': 'OTHER', 'start': 191908, 'end': 198808}, {'label': 'REC_WORD', 'start': 198810, 'end': 202510}, {'label': 'OTHER', 'start': 202511, 'end': 203925}]
# Processing interval 0: start=154100, end=159300, segment length=5200, t_offset=308.2000
# Processing segment of length 5200 with t_offset=308.2000
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=308.34999999999997, last_t=318.5500
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=159301, end=160501, segment length=1200, t_offset=318.6020
# Processing segment of length 1200 with t_offset=318.6020
# Preparing signal segment, original length: 1200
# Signal segment length after padding: 1250
# STFT raw output: len(f) = 76 len(t) = 12 Zxx shape = (76, 12)
# STFT after normalization: len(t) = 12
# Interval processed: new t[0]=318.75199999999995, last_t=320.9520
# Interval 1: expected bins=12.0, actual bins=12, diff=0.0
# Processing interval 2: start=160502, end=175202, segment length=14700, t_offset=321.0040
# Processing segment of length 14700 with t_offset=321.0040
# Preparing signal segment, original length: 14700
# Signal segment length after padding: 14750
# STFT raw output: len(f) = 76 len(t) = 147 Zxx shape = (76, 147)
# STFT after normalization: len(t) = 147
# Interval processed: new t[0]=321.154, last_t=350.3540
# Interval 2: expected bins=147.0, actual bins=147, diff=0.0
# Processing interval 3: start=175204, end=186904, segment length=11700, t_offset=350.4080
# Processing segment of length 11700 with t_offset=350.4080
# Preparing signal segment, original length: 11700
# Signal segment length after padding: 11750
# STFT raw output: len(f) = 76 len(t) = 117 Zxx shape = (76, 117)
# STFT after normalization: len(t) = 117
# Interval processed: new t[0]=350.558, last_t=373.7580
# Interval 3: expected bins=117.0, actual bins=117, diff=0.0
# Processing interval 4: start=186906, end=189606, segment length=2700, t_offset=373.8120
# Processing segment of length 2700 with t_offset=373.8120
# Preparing signal segment, original length: 2700
# Signal segment length after padding: 2750
# STFT raw output: len(f) = 76 len(t) = 27 Zxx shape = (76, 27)
# STFT after normalization: len(t) = 27
# Interval processed: new t[0]=373.962, last_t=379.1620
# Interval 4: expected bins=27.0, actual bins=27, diff=0.0
# Processing interval 5: start=189607, end=191907, segment length=2300, t_offset=379.2140
# Processing segment of length 2300 with t_offset=379.2140
# Preparing signal segment, original length: 2300
# Signal segment length after padding: 2350
# STFT raw output: len(f) = 76 len(t) = 23 Zxx shape = (76, 23)
# STFT after normalization: len(t) = 23
# Interval processed: new t[0]=379.364, last_t=383.7640
# Interval 5: expected bins=23.0, actual bins=23, diff=0.0
# Processing interval 6: start=191908, end=198808, segment length=6900, t_offset=383.8160
# Processing segment of length 6900 with t_offset=383.8160
# Preparing signal segment, original length: 6900
# Signal segment length after padding: 6950
# STFT raw output: len(f) = 76 len(t) = 69 Zxx shape = (76, 69)
# STFT after normalization: len(t) = 69
# Interval processed: new t[0]=383.96599999999995, last_t=397.5660
# Interval 6: expected bins=69.0, actual bins=69, diff=0.0
# Processing interval 7: start=198810, end=202510, segment length=3700, t_offset=397.6200
# Processing segment of length 3700 with t_offset=397.6200
# Preparing signal segment, original length: 3700
# Signal segment length after padding: 3750
# STFT raw output: len(f) = 76 len(t) = 37 Zxx shape = (76, 37)
# STFT after normalization: len(t) = 37
# Interval processed: new t[0]=397.77, last_t=404.9700
# Interval 7: expected bins=37.0, actual bins=37, diff=0.0
# Processing interval 8: start=202511, end=203925, segment length=1414, t_offset=405.0220
# Processing segment of length 1414 with t_offset=405.0220
# Preparing signal segment, original length: 1414
# Signal segment length after padding: 1464
# STFT raw output: len(f) = 76 len(t) = 15 Zxx shape = (76, 15)
# STFT after normalization: len(t) = 15
# Interval processed: new t[0]=405.17199999999997, last_t=407.9720
# Interval 8: expected bins=14.14, actual bins=15, diff=0.8599999999999994
# 1,-0.1190000000000282
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  203926  209143
# 1      OTHER  209144  210452
# 2       WORD  210453  225205
# 3      OTHER  225206  225213
# 4       PROB  225214  235280
# 5      OTHER  235281  236774
# 6   REC_WORD  236775  243133
# 7      OTHER  243134  244022
# 8   REC_WORD  244023  250821
# 9      OTHER  250822  253760
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 203926, 'end': 209143}, {'label': 'OTHER', 'start': 209144, 'end': 210452}, {'label': 'WORD', 'start': 210453, 'end': 225205}, {'label': 'OTHER', 'start': 225206, 'end': 225213}, {'label': 'PROB', 'start': 225214, 'end': 235280}, {'label': 'OTHER', 'start': 235281, 'end': 236774}, {'label': 'REC_WORD', 'start': 236775, 'end': 243133}, {'label': 'OTHER', 'start': 243134, 'end': 244022}, {'label': 'REC_WORD', 'start': 244023, 'end': 250821}, {'label': 'OTHER', 'start': 250822, 'end': 253760}]
# Processing interval 0: start=203926, end=209143, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 209126, next interval new start: 209127
# Processing interval 1: start=209127, end=210452, length=1325, modulo=25, division=13
# Adjusted interval 1 with modulo 25, new end: 210427, next interval new start: 210428
# Processing interval 2: start=210428, end=225205, length=14777, modulo=77, division=147
# Interval 2 modulo > threshold, needed=23, next interval available=7
# Merged interval 2 with next interval, new end: 225213
# Processing interval 2: start=210428, end=225213, length=14785, modulo=85, division=147
# Interval 2 modulo > threshold, needed=15, next interval available=10066
# Extended interval 2 by 15 samples, new end: 225228, next interval new start: 225230
# Processing interval 3: start=225230, end=235280, length=10050, modulo=50, division=100
# Adjusted interval 3 with modulo 50, new end: 235230, next interval new start: 235231
# Processing interval 4: start=235231, end=236774, length=1543, modulo=43, division=15
# Adjusted interval 4 with modulo 43, new end: 236731, next interval new start: 236732
# Processing interval 5: start=236732, end=243133, length=6401, modulo=1, division=64
# Adjusted interval 5 with modulo 1, new end: 243132, next interval new start: 243133
# Processing interval 6: start=243133, end=244022, length=889, modulo=89, division=8
# Interval 6 modulo > threshold, needed=11, next interval available=6798
# Extended interval 6 by 11 samples, new end: 244033, next interval new start: 244035
# Processing interval 7: start=244035, end=250821, length=6786, modulo=86, division=67
# Interval 7 modulo > threshold, needed=14, next interval available=2938
# Extended interval 7 by 14 samples, new end: 250835, next interval new start: 250837
# Processing interval 8: start=250837, end=253760, length=2923, modulo=23, division=29
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 203926, 'end': 209126}, {'label': 'OTHER', 'start': 209127, 'end': 210427}, {'label': 'WORD', 'start': 210428, 'end': 225228}, {'label': 'PROB', 'start': 225230, 'end': 235230}, {'label': 'OTHER', 'start': 235231, 'end': 236731}, {'label': 'REC_WORD', 'start': 236732, 'end': 243132}, {'label': 'OTHER', 'start': 243133, 'end': 244033}, {'label': 'REC_WORD', 'start': 244035, 'end': 250835}, {'label': 'OTHER', 'start': 250837, 'end': 253760}]
# Processing interval 0: start=203926, end=209126, segment length=5200, t_offset=407.8520
# Processing segment of length 5200 with t_offset=407.8520
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=408.00199999999995, last_t=418.2020
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=209127, end=210427, segment length=1300, t_offset=418.2540
# Processing segment of length 1300 with t_offset=418.2540
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=418.404, last_t=420.8040
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=210428, end=225228, segment length=14800, t_offset=420.8560
# Processing segment of length 14800 with t_offset=420.8560
# Preparing signal segment, original length: 14800
# Signal segment length after padding: 14850
# STFT raw output: len(f) = 76 len(t) = 148 Zxx shape = (76, 148)
# STFT after normalization: len(t) = 148
# Interval processed: new t[0]=421.006, last_t=450.4060
# Interval 2: expected bins=148.0, actual bins=148, diff=0.0
# Processing interval 3: start=225230, end=235230, segment length=10000, t_offset=450.4600
# Processing segment of length 10000 with t_offset=450.4600
# Preparing signal segment, original length: 10000
# Signal segment length after padding: 10050
# STFT raw output: len(f) = 76 len(t) = 100 Zxx shape = (76, 100)
# STFT after normalization: len(t) = 100
# Interval processed: new t[0]=450.60999999999996, last_t=470.4100
# Interval 3: expected bins=100.0, actual bins=100, diff=0.0
# Processing interval 4: start=235231, end=236731, segment length=1500, t_offset=470.4620
# Processing segment of length 1500 with t_offset=470.4620
# Preparing signal segment, original length: 1500
# Signal segment length after padding: 1550
# STFT raw output: len(f) = 76 len(t) = 15 Zxx shape = (76, 15)
# STFT after normalization: len(t) = 15
# Interval processed: new t[0]=470.61199999999997, last_t=473.4120
# Interval 4: expected bins=15.0, actual bins=15, diff=0.0
# Processing interval 5: start=236732, end=243132, segment length=6400, t_offset=473.4640
# Processing segment of length 6400 with t_offset=473.4640
# Preparing signal segment, original length: 6400
# Signal segment length after padding: 6450
# STFT raw output: len(f) = 76 len(t) = 64 Zxx shape = (76, 64)
# STFT after normalization: len(t) = 64
# Interval processed: new t[0]=473.614, last_t=486.2140
# Interval 5: expected bins=64.0, actual bins=64, diff=0.0
# Processing interval 6: start=243133, end=244033, segment length=900, t_offset=486.2660
# Processing segment of length 900 with t_offset=486.2660
# Preparing signal segment, original length: 900
# Signal segment length after padding: 950
# STFT raw output: len(f) = 76 len(t) = 9 Zxx shape = (76, 9)
# STFT after normalization: len(t) = 9
# Interval processed: new t[0]=486.416, last_t=488.0160
# Interval 6: expected bins=9.0, actual bins=9, diff=0.0
# Processing interval 7: start=244035, end=250835, segment length=6800, t_offset=488.0700
# Processing segment of length 6800 with t_offset=488.0700
# Preparing signal segment, original length: 6800
# Signal segment length after padding: 6850
# STFT raw output: len(f) = 76 len(t) = 68 Zxx shape = (76, 68)
# STFT after normalization: len(t) = 68
# Interval processed: new t[0]=488.21999999999997, last_t=501.6200
# Interval 7: expected bins=68.0, actual bins=68, diff=0.0
# Processing interval 8: start=250837, end=253760, segment length=2923, t_offset=501.6740
# Processing segment of length 2923 with t_offset=501.6740
# Preparing signal segment, original length: 2923
# Signal segment length after padding: 2973
# STFT raw output: len(f) = 76 len(t) = 30 Zxx shape = (76, 30)
# STFT after normalization: len(t) = 30
# Interval processed: new t[0]=501.82399999999996, last_t=507.6240
# Interval 8: expected bins=29.23, actual bins=30, diff=0.7699999999999996
# 2,-0.10199999999997544
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  253761  258977
# 1      OTHER  258978  260228
# 2       WORD  260229  274781
# 3      OTHER  274782  274789
# 4       PROB  274790  286080
# 5      OTHER  286081  288477
# 6   REC_WORD  288478  293495
# 7      OTHER  293496  293701
# 8   REC_WORD  293702  301697
# 9      OTHER  301698  307603
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 253761, 'end': 258977}, {'label': 'OTHER', 'start': 258978, 'end': 260228}, {'label': 'WORD', 'start': 260229, 'end': 274781}, {'label': 'OTHER', 'start': 274782, 'end': 274789}, {'label': 'PROB', 'start': 274790, 'end': 286080}, {'label': 'OTHER', 'start': 286081, 'end': 288477}, {'label': 'REC_WORD', 'start': 288478, 'end': 293495}, {'label': 'OTHER', 'start': 293496, 'end': 293701}, {'label': 'REC_WORD', 'start': 293702, 'end': 301697}, {'label': 'OTHER', 'start': 301698, 'end': 307603}]
# Processing interval 0: start=253761, end=258977, length=5216, modulo=16, division=52
# Adjusted interval 0 with modulo 16, new end: 258961, next interval new start: 258962
# Processing interval 1: start=258962, end=260228, length=1266, modulo=66, division=12
# Interval 1 modulo > threshold, needed=34, next interval available=14552
# Extended interval 1 by 34 samples, new end: 260262, next interval new start: 260264
# Processing interval 2: start=260264, end=274781, length=14517, modulo=17, division=145
# Adjusted interval 2 with modulo 17, new end: 274764, next interval new start: 274765
# Processing interval 3: start=274765, end=274789, length=24, modulo=24, division=0
# Discarding interval 3 as it has no valid length
# Processing interval 3: start=274790, end=286080, length=11290, modulo=90, division=112
# Interval 3 modulo > threshold, needed=10, next interval available=2396
# Extended interval 3 by 10 samples, new end: 286090, next interval new start: 286092
# Processing interval 4: start=286092, end=288477, length=2385, modulo=85, division=23
# Interval 4 modulo > threshold, needed=15, next interval available=5017
# Extended interval 4 by 15 samples, new end: 288492, next interval new start: 288494
# Processing interval 5: start=288494, end=293495, length=5001, modulo=1, division=50
# Adjusted interval 5 with modulo 1, new end: 293494, next interval new start: 293495
# Processing interval 6: start=293495, end=293701, length=206, modulo=6, division=2
# Adjusted interval 6 with modulo 6, new end: 293695, next interval new start: 293696
# Processing interval 7: start=293696, end=301697, length=8001, modulo=1, division=80
# Adjusted interval 7 with modulo 1, new end: 301696, next interval new start: 301697
# Processing interval 8: start=301697, end=307603, length=5906, modulo=6, division=59
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 253761, 'end': 258961}, {'label': 'OTHER', 'start': 258962, 'end': 260262}, {'label': 'WORD', 'start': 260264, 'end': 274764}, {'label': 'PROB', 'start': 274790, 'end': 286090}, {'label': 'OTHER', 'start': 286092, 'end': 288492}, {'label': 'REC_WORD', 'start': 288494, 'end': 293494}, {'label': 'OTHER', 'start': 293495, 'end': 293695}, {'label': 'REC_WORD', 'start': 293696, 'end': 301696}, {'label': 'OTHER', 'start': 301697, 'end': 307603}]
# Processing interval 0: start=253761, end=258961, segment length=5200, t_offset=507.5220
# Processing segment of length 5200 with t_offset=507.5220
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=507.67199999999997, last_t=517.8720
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=258962, end=260262, segment length=1300, t_offset=517.9240
# Processing segment of length 1300 with t_offset=517.9240
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=518.074, last_t=520.4740
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=260264, end=274764, segment length=14500, t_offset=520.5280
# Processing segment of length 14500 with t_offset=520.5280
# Preparing signal segment, original length: 14500
# Signal segment length after padding: 14550
# STFT raw output: len(f) = 76 len(t) = 145 Zxx shape = (76, 145)
# STFT after normalization: len(t) = 145
# Interval processed: new t[0]=520.678, last_t=549.4780
# Interval 2: expected bins=145.0, actual bins=145, diff=0.0
# Processing interval 3: start=274790, end=286090, segment length=11300, t_offset=549.5800
# Processing segment of length 11300 with t_offset=549.5800
# Preparing signal segment, original length: 11300
# Signal segment length after padding: 11350
# STFT raw output: len(f) = 76 len(t) = 113 Zxx shape = (76, 113)
# STFT after normalization: len(t) = 113
# Interval processed: new t[0]=549.73, last_t=572.1300
# Interval 3: expected bins=113.0, actual bins=113, diff=0.0
# Processing interval 4: start=286092, end=288492, segment length=2400, t_offset=572.1840
# Processing segment of length 2400 with t_offset=572.1840
# Preparing signal segment, original length: 2400
# Signal segment length after padding: 2450
# STFT raw output: len(f) = 76 len(t) = 24 Zxx shape = (76, 24)
# STFT after normalization: len(t) = 24
# Interval processed: new t[0]=572.334, last_t=576.9340
# Interval 4: expected bins=24.0, actual bins=24, diff=0.0
# Processing interval 5: start=288494, end=293494, segment length=5000, t_offset=576.9880
# Processing segment of length 5000 with t_offset=576.9880
# Preparing signal segment, original length: 5000
# Signal segment length after padding: 5050
# STFT raw output: len(f) = 76 len(t) = 50 Zxx shape = (76, 50)
# STFT after normalization: len(t) = 50
# Interval processed: new t[0]=577.138, last_t=586.9380
# Interval 5: expected bins=50.0, actual bins=50, diff=0.0
# Processing interval 6: start=293495, end=293695, segment length=200, t_offset=586.9900
# Processing segment of length 200 with t_offset=586.9900
# Preparing signal segment, original length: 200
# Signal segment length after padding: 250
# STFT raw output: len(f) = 76 len(t) = 2 Zxx shape = (76, 2)
# STFT after normalization: len(t) = 2
# Interval processed: new t[0]=587.14, last_t=587.3400
# Interval 6: expected bins=2.0, actual bins=2, diff=0.0
# Processing interval 7: start=293696, end=301696, segment length=8000, t_offset=587.3920
# Processing segment of length 8000 with t_offset=587.3920
# Preparing signal segment, original length: 8000
# Signal segment length after padding: 8050
# STFT raw output: len(f) = 76 len(t) = 80 Zxx shape = (76, 80)
# STFT after normalization: len(t) = 80
# Interval processed: new t[0]=587.542, last_t=603.3420
# Interval 7: expected bins=80.0, actual bins=80, diff=0.0
# Processing interval 8: start=301697, end=307603, segment length=5906, t_offset=603.3940
# Processing segment of length 5906 with t_offset=603.3940
# Preparing signal segment, original length: 5906
# Signal segment length after padding: 5956
# STFT raw output: len(f) = 76 len(t) = 60 Zxx shape = (76, 60)
# STFT after normalization: len(t) = 60
# Interval processed: new t[0]=603.544, last_t=615.3440
# Interval 8: expected bins=59.06, actual bins=60, diff=0.9399999999999977
# 3,-0.1350000000001046
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  307604  312821
# 1      OTHER  312822  314046
# 2       WORD  314047  328457
# 3      OTHER  328458  328465
# 4       PROB  328466  338576
# 5      OTHER  338577  355687
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 307604, 'end': 312821}, {'label': 'OTHER', 'start': 312822, 'end': 314046}, {'label': 'WORD', 'start': 314047, 'end': 328457}, {'label': 'OTHER', 'start': 328458, 'end': 328465}, {'label': 'PROB', 'start': 328466, 'end': 338576}, {'label': 'OTHER', 'start': 338577, 'end': 355687}]
# Processing interval 0: start=307604, end=312821, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 312804, next interval new start: 312805
# Processing interval 1: start=312805, end=314046, length=1241, modulo=41, division=12
# Adjusted interval 1 with modulo 41, new end: 314005, next interval new start: 314006
# Processing interval 2: start=314006, end=328457, length=14451, modulo=51, division=144
# Interval 2 modulo > threshold, needed=49, next interval available=7
# Merged interval 2 with next interval, new end: 328465
# Processing interval 2: start=314006, end=328465, length=14459, modulo=59, division=144
# Interval 2 modulo > threshold, needed=41, next interval available=10110
# Extended interval 2 by 41 samples, new end: 328506, next interval new start: 328508
# Processing interval 3: start=328508, end=338576, length=10068, modulo=68, division=100
# Interval 3 modulo > threshold, needed=32, next interval available=17110
# Extended interval 3 by 32 samples, new end: 338608, next interval new start: 338610
# Processing interval 4: start=338610, end=355687, length=17077, modulo=77, division=170
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 307604, 'end': 312804}, {'label': 'OTHER', 'start': 312805, 'end': 314005}, {'label': 'WORD', 'start': 314006, 'end': 328506}, {'label': 'PROB', 'start': 328508, 'end': 338608}, {'label': 'OTHER', 'start': 338610, 'end': 355687}]
# Processing interval 0: start=307604, end=312804, segment length=5200, t_offset=615.2080
# Processing segment of length 5200 with t_offset=615.2080
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=615.358, last_t=625.5580
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=312805, end=314005, segment length=1200, t_offset=625.6100
# Processing segment of length 1200 with t_offset=625.6100
# Preparing signal segment, original length: 1200
# Signal segment length after padding: 1250
# STFT raw output: len(f) = 76 len(t) = 12 Zxx shape = (76, 12)
# STFT after normalization: len(t) = 12
# Interval processed: new t[0]=625.76, last_t=627.9600
# Interval 1: expected bins=12.0, actual bins=12, diff=0.0
# Processing interval 2: start=314006, end=328506, segment length=14500, t_offset=628.0120
# Processing segment of length 14500 with t_offset=628.0120
# Preparing signal segment, original length: 14500
# Signal segment length after padding: 14550
# STFT raw output: len(f) = 76 len(t) = 145 Zxx shape = (76, 145)
# STFT after normalization: len(t) = 145
# Interval processed: new t[0]=628.1619999999999, last_t=656.9620
# Interval 2: expected bins=145.0, actual bins=145, diff=0.0
# Processing interval 3: start=328508, end=338608, segment length=10100, t_offset=657.0160
# Processing segment of length 10100 with t_offset=657.0160
# Preparing signal segment, original length: 10100
# Signal segment length after padding: 10150
# STFT raw output: len(f) = 76 len(t) = 101 Zxx shape = (76, 101)
# STFT after normalization: len(t) = 101
# Interval processed: new t[0]=657.1659999999999, last_t=677.1660
# Interval 3: expected bins=101.0, actual bins=101, diff=0.0
# Processing interval 4: start=338610, end=355687, segment length=17077, t_offset=677.2200
# Processing segment of length 17077 with t_offset=677.2200
# Preparing signal segment, original length: 17077
# Signal segment length after padding: 17127
# STFT raw output: len(f) = 76 len(t) = 171 Zxx shape = (76, 171)
# STFT after normalization: len(t) = 171
# Interval processed: new t[0]=677.37, last_t=711.3700
# Interval 4: expected bins=170.77, actual bins=171, diff=0.22999999999998977
# 4,0.006999999999948159
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  355688  360905
# 1      OTHER  360906  362097
# 2       WORD  362098  376517
# 3      OTHER  376518  376525
# 4       PROB  376526  390680
# 5      OTHER  390681  535929
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 355688, 'end': 360905}, {'label': 'OTHER', 'start': 360906, 'end': 362097}, {'label': 'WORD', 'start': 362098, 'end': 376517}, {'label': 'OTHER', 'start': 376518, 'end': 376525}, {'label': 'PROB', 'start': 376526, 'end': 390680}, {'label': 'OTHER', 'start': 390681, 'end': 535929}]
# Processing interval 0: start=355688, end=360905, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 360888, next interval new start: 360889
# Processing interval 1: start=360889, end=362097, length=1208, modulo=8, division=12
# Adjusted interval 1 with modulo 8, new end: 362089, next interval new start: 362090
# Processing interval 2: start=362090, end=376517, length=14427, modulo=27, division=144
# Adjusted interval 2 with modulo 27, new end: 376490, next interval new start: 376491
# Processing interval 3: start=376491, end=376525, length=34, modulo=34, division=0
# Discarding interval 3 as it has no valid length
# Processing interval 3: start=376526, end=390680, length=14154, modulo=54, division=141
# Interval 3 modulo > threshold, needed=46, next interval available=145248
# Extended interval 3 by 46 samples, new end: 390726, next interval new start: 390728
# Processing interval 4: start=390728, end=535929, length=145201, modulo=1, division=1452
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 355688, 'end': 360888}, {'label': 'OTHER', 'start': 360889, 'end': 362089}, {'label': 'WORD', 'start': 362090, 'end': 376490}, {'label': 'PROB', 'start': 376526, 'end': 390726}, {'label': 'OTHER', 'start': 390728, 'end': 535929}]
# Processing interval 0: start=355688, end=360888, segment length=5200, t_offset=711.3760
# Processing segment of length 5200 with t_offset=711.3760
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=711.526, last_t=721.7260
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=360889, end=362089, segment length=1200, t_offset=721.7780
# Processing segment of length 1200 with t_offset=721.7780
# Preparing signal segment, original length: 1200
# Signal segment length after padding: 1250
# STFT raw output: len(f) = 76 len(t) = 12 Zxx shape = (76, 12)
# STFT after normalization: len(t) = 12
# Interval processed: new t[0]=721.928, last_t=724.1280
# Interval 1: expected bins=12.0, actual bins=12, diff=0.0
# Processing interval 2: start=362090, end=376490, segment length=14400, t_offset=724.1800
# Processing segment of length 14400 with t_offset=724.1800
# Preparing signal segment, original length: 14400
# Signal segment length after padding: 14450
# STFT raw output: len(f) = 76 len(t) = 144 Zxx shape = (76, 144)
# STFT after normalization: len(t) = 144
# Interval processed: new t[0]=724.3299999999999, last_t=752.9300
# Interval 2: expected bins=144.0, actual bins=144, diff=0.0
# Processing interval 3: start=376526, end=390726, segment length=14200, t_offset=753.0520
# Processing segment of length 14200 with t_offset=753.0520
# Preparing signal segment, original length: 14200
# Signal segment length after padding: 14250
# STFT raw output: len(f) = 76 len(t) = 142 Zxx shape = (76, 142)
# STFT after normalization: len(t) = 142
# Interval processed: new t[0]=753.202, last_t=781.4020
# Interval 3: expected bins=142.0, actual bins=142, diff=0.0
# Processing interval 4: start=390728, end=535929, segment length=145201, t_offset=781.4560
# Processing segment of length 145201 with t_offset=781.4560
# Preparing signal segment, original length: 145201
# Signal segment length after padding: 145251
# STFT raw output: len(f) = 76 len(t) = 1453 Zxx shape = (76, 1453)
# STFT after normalization: len(t) = 1453
# Interval processed: new t[0]=781.606, last_t=1072.0060
# Interval 4: expected bins=1452.01, actual bins=1453, diff=0.9900000000000091
# 5,-0.14500000000020918
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  535930  541147
# 1      OTHER  541148  542439
# 2       WORD  542440  557059
# 3      OTHER  557060  557067
# 4       PROB  557068  572548
# 5      OTHER  572549  578877
# 6   REC_WORD  578878  588134
# 7      OTHER  588135  592132
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 535930, 'end': 541147}, {'label': 'OTHER', 'start': 541148, 'end': 542439}, {'label': 'WORD', 'start': 542440, 'end': 557059}, {'label': 'OTHER', 'start': 557060, 'end': 557067}, {'label': 'PROB', 'start': 557068, 'end': 572548}, {'label': 'OTHER', 'start': 572549, 'end': 578877}, {'label': 'REC_WORD', 'start': 578878, 'end': 588134}, {'label': 'OTHER', 'start': 588135, 'end': 592132}]
# Processing interval 0: start=535930, end=541147, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 541130, next interval new start: 541131
# Processing interval 1: start=541131, end=542439, length=1308, modulo=8, division=13
# Adjusted interval 1 with modulo 8, new end: 542431, next interval new start: 542432
# Processing interval 2: start=542432, end=557059, length=14627, modulo=27, division=146
# Adjusted interval 2 with modulo 27, new end: 557032, next interval new start: 557033
# Processing interval 3: start=557033, end=557067, length=34, modulo=34, division=0
# Discarding interval 3 as it has no valid length
# Processing interval 3: start=557068, end=572548, length=15480, modulo=80, division=154
# Interval 3 modulo > threshold, needed=20, next interval available=6328
# Extended interval 3 by 20 samples, new end: 572568, next interval new start: 572570
# Processing interval 4: start=572570, end=578877, length=6307, modulo=7, division=63
# Adjusted interval 4 with modulo 7, new end: 578870, next interval new start: 578871
# Processing interval 5: start=578871, end=588134, length=9263, modulo=63, division=92
# Interval 5 modulo > threshold, needed=37, next interval available=3997
# Extended interval 5 by 37 samples, new end: 588171, next interval new start: 588173
# Processing interval 6: start=588173, end=592132, length=3959, modulo=59, division=39
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 535930, 'end': 541130}, {'label': 'OTHER', 'start': 541131, 'end': 542431}, {'label': 'WORD', 'start': 542432, 'end': 557032}, {'label': 'PROB', 'start': 557068, 'end': 572568}, {'label': 'OTHER', 'start': 572570, 'end': 578870}, {'label': 'REC_WORD', 'start': 578871, 'end': 588171}, {'label': 'OTHER', 'start': 588173, 'end': 592132}]
# Processing interval 0: start=535930, end=541130, segment length=5200, t_offset=1071.8600
# Processing segment of length 5200 with t_offset=1071.8600
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=1072.01, last_t=1082.2100
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=541131, end=542431, segment length=1300, t_offset=1082.2620
# Processing segment of length 1300 with t_offset=1082.2620
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=1082.412, last_t=1084.8120
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=542432, end=557032, segment length=14600, t_offset=1084.8640
# Processing segment of length 14600 with t_offset=1084.8640
# Preparing signal segment, original length: 14600
# Signal segment length after padding: 14650
# STFT raw output: len(f) = 76 len(t) = 146 Zxx shape = (76, 146)
# STFT after normalization: len(t) = 146
# Interval processed: new t[0]=1085.0140000000001, last_t=1114.0140
# Interval 2: expected bins=146.0, actual bins=146, diff=0.0
# Processing interval 3: start=557068, end=572568, segment length=15500, t_offset=1114.1360
# Processing segment of length 15500 with t_offset=1114.1360
# Preparing signal segment, original length: 15500
# Signal segment length after padding: 15550
# STFT raw output: len(f) = 76 len(t) = 155 Zxx shape = (76, 155)
# STFT after normalization: len(t) = 155
# Interval processed: new t[0]=1114.286, last_t=1145.0860
# Interval 3: expected bins=155.0, actual bins=155, diff=0.0
# Processing interval 4: start=572570, end=578870, segment length=6300, t_offset=1145.1400
# Processing segment of length 6300 with t_offset=1145.1400
# Preparing signal segment, original length: 6300
# Signal segment length after padding: 6350
# STFT raw output: len(f) = 76 len(t) = 63 Zxx shape = (76, 63)
# STFT after normalization: len(t) = 63
# Interval processed: new t[0]=1145.2900000000002, last_t=1157.6900
# Interval 4: expected bins=63.0, actual bins=63, diff=0.0
# Processing interval 5: start=578871, end=588171, segment length=9300, t_offset=1157.7420
# Processing segment of length 9300 with t_offset=1157.7420
# Preparing signal segment, original length: 9300
# Signal segment length after padding: 9350
# STFT raw output: len(f) = 76 len(t) = 93 Zxx shape = (76, 93)
# STFT after normalization: len(t) = 93
# Interval processed: new t[0]=1157.892, last_t=1176.2920
# Interval 5: expected bins=93.0, actual bins=93, diff=0.0
# Processing interval 6: start=588173, end=592132, segment length=3959, t_offset=1176.3460
# Processing segment of length 3959 with t_offset=1176.3460
# Preparing signal segment, original length: 3959
# Signal segment length after padding: 4009
# STFT raw output: len(f) = 76 len(t) = 40 Zxx shape = (76, 40)
# STFT after normalization: len(t) = 40
# Interval processed: new t[0]=1176.496, last_t=1184.2960
# Interval 6: expected bins=39.59, actual bins=40, diff=0.4099999999999966
# 6,-0.029999999999972715
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  592133  597349
# 1      OTHER  597350  598599
# 2       WORD  598600  613003
# 3      OTHER  613004  613011
# 4       PROB  613012  631648
# 5      OTHER  631649  639183
# 6   REC_WORD  639184  647247
# 7      OTHER  647248  654460
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 592133, 'end': 597349}, {'label': 'OTHER', 'start': 597350, 'end': 598599}, {'label': 'WORD', 'start': 598600, 'end': 613003}, {'label': 'OTHER', 'start': 613004, 'end': 613011}, {'label': 'PROB', 'start': 613012, 'end': 631648}, {'label': 'OTHER', 'start': 631649, 'end': 639183}, {'label': 'REC_WORD', 'start': 639184, 'end': 647247}, {'label': 'OTHER', 'start': 647248, 'end': 654460}]
# Processing interval 0: start=592133, end=597349, length=5216, modulo=16, division=52
# Adjusted interval 0 with modulo 16, new end: 597333, next interval new start: 597334
# Processing interval 1: start=597334, end=598599, length=1265, modulo=65, division=12
# Interval 1 modulo > threshold, needed=35, next interval available=14403
# Extended interval 1 by 35 samples, new end: 598634, next interval new start: 598636
# Processing interval 2: start=598636, end=613003, length=14367, modulo=67, division=143
# Interval 2 modulo > threshold, needed=33, next interval available=7
# Merged interval 2 with next interval, new end: 613011
# Processing interval 2: start=598636, end=613011, length=14375, modulo=75, division=143
# Interval 2 modulo > threshold, needed=25, next interval available=18636
# Extended interval 2 by 25 samples, new end: 613036, next interval new start: 613038
# Processing interval 3: start=613038, end=631648, length=18610, modulo=10, division=186
# Adjusted interval 3 with modulo 10, new end: 631638, next interval new start: 631639
# Processing interval 4: start=631639, end=639183, length=7544, modulo=44, division=75
# Adjusted interval 4 with modulo 44, new end: 639139, next interval new start: 639140
# Processing interval 5: start=639140, end=647247, length=8107, modulo=7, division=81
# Adjusted interval 5 with modulo 7, new end: 647240, next interval new start: 647241
# Processing interval 6: start=647241, end=654460, length=7219, modulo=19, division=72
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 592133, 'end': 597333}, {'label': 'OTHER', 'start': 597334, 'end': 598634}, {'label': 'WORD', 'start': 598636, 'end': 613036}, {'label': 'PROB', 'start': 613038, 'end': 631638}, {'label': 'OTHER', 'start': 631639, 'end': 639139}, {'label': 'REC_WORD', 'start': 639140, 'end': 647240}, {'label': 'OTHER', 'start': 647241, 'end': 654460}]
# Processing interval 0: start=592133, end=597333, segment length=5200, t_offset=1184.2660
# Processing segment of length 5200 with t_offset=1184.2660
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=1184.4160000000002, last_t=1194.6160
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=597334, end=598634, segment length=1300, t_offset=1194.6680
# Processing segment of length 1300 with t_offset=1194.6680
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=1194.818, last_t=1197.2180
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=598636, end=613036, segment length=14400, t_offset=1197.2720
# Processing segment of length 14400 with t_offset=1197.2720
# Preparing signal segment, original length: 14400
# Signal segment length after padding: 14450
# STFT raw output: len(f) = 76 len(t) = 144 Zxx shape = (76, 144)
# STFT after normalization: len(t) = 144
# Interval processed: new t[0]=1197.422, last_t=1226.0220
# Interval 2: expected bins=144.0, actual bins=144, diff=0.0
# Processing interval 3: start=613038, end=631638, segment length=18600, t_offset=1226.0760
# Processing segment of length 18600 with t_offset=1226.0760
# Preparing signal segment, original length: 18600
# Signal segment length after padding: 18650
# STFT raw output: len(f) = 76 len(t) = 186 Zxx shape = (76, 186)
# STFT after normalization: len(t) = 186
# Interval processed: new t[0]=1226.226, last_t=1263.2260
# Interval 3: expected bins=186.0, actual bins=186, diff=0.0
# Processing interval 4: start=631639, end=639139, segment length=7500, t_offset=1263.2780
# Processing segment of length 7500 with t_offset=1263.2780
# Preparing signal segment, original length: 7500
# Signal segment length after padding: 7550
# STFT raw output: len(f) = 76 len(t) = 75 Zxx shape = (76, 75)
# STFT after normalization: len(t) = 75
# Interval processed: new t[0]=1263.428, last_t=1278.2280
# Interval 4: expected bins=75.0, actual bins=75, diff=0.0
# Processing interval 5: start=639140, end=647240, segment length=8100, t_offset=1278.2800
# Processing segment of length 8100 with t_offset=1278.2800
# Preparing signal segment, original length: 8100
# Signal segment length after padding: 8150
# STFT raw output: len(f) = 76 len(t) = 81 Zxx shape = (76, 81)
# STFT after normalization: len(t) = 81
# Interval processed: new t[0]=1278.43, last_t=1294.4300
# Interval 5: expected bins=81.0, actual bins=81, diff=0.0
# Processing interval 6: start=647241, end=654460, segment length=7219, t_offset=1294.4820
# Processing segment of length 7219 with t_offset=1294.4820
# Preparing signal segment, original length: 7219
# Signal segment length after padding: 7269
# STFT raw output: len(f) = 76 len(t) = 73 Zxx shape = (76, 73)
# STFT after normalization: len(t) = 73
# Interval processed: new t[0]=1294.632, last_t=1309.0320
# Interval 6: expected bins=72.19, actual bins=73, diff=0.8100000000000023
# 7,-0.10999999999989996
# Converted intervals to samples:
#        label   start     end
# 0  COUNTDOWN  654461  659678
# 1      OTHER  659679  660953
# 2       WORD  660954  675506
# 3      OTHER  675507  675514
# 4       PROB  675515  688108
# 5      OTHER  688109  690473
# 6   REC_WORD  690474  703722
# 7      OTHER  703723  710404
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 654461, 'end': 659678}, {'label': 'OTHER', 'start': 659679, 'end': 660953}, {'label': 'WORD', 'start': 660954, 'end': 675506}, {'label': 'OTHER', 'start': 675507, 'end': 675514}, {'label': 'PROB', 'start': 675515, 'end': 688108}, {'label': 'OTHER', 'start': 688109, 'end': 690473}, {'label': 'REC_WORD', 'start': 690474, 'end': 703722}, {'label': 'OTHER', 'start': 703723, 'end': 710404}]
# Processing interval 0: start=654461, end=659678, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 659661, next interval new start: 659662
# Processing interval 1: start=659662, end=660953, length=1291, modulo=91, division=12
# Interval 1 modulo > threshold, needed=9, next interval available=14552
# Extended interval 1 by 9 samples, new end: 660962, next interval new start: 660964
# Processing interval 2: start=660964, end=675506, length=14542, modulo=42, division=145
# Adjusted interval 2 with modulo 42, new end: 675464, next interval new start: 675465
# Processing interval 3: start=675465, end=675514, length=49, modulo=49, division=0
# Discarding interval 3 as it has no valid length
# Processing interval 3: start=675515, end=688108, length=12593, modulo=93, division=125
# Interval 3 modulo > threshold, needed=7, next interval available=2364
# ...
# Processing interval 0: start=1610732, end=1615932, segment length=5200, t_offset=3221.4640
# Processing segment of length 5200 with t_offset=3221.4640
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=3221.614, last_t=3231.8140
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=1615933, end=1617133, segment length=1200, t_offset=3231.8660
# Processing segment of length 1200 with t_offset=3231.8660
# Preparing signal segment, original length: 1200
# Signal segment length after padding: 1250
# STFT raw output: len(f) = 76 len(t) = 12 Zxx shape = (76, 12)
# STFT after normalization: len(t) = 12
# Interval processed: new t[0]=3232.016, last_t=3234.2160
# Interval 1: expected bins=12.0, actual bins=12, diff=0.0
# Processing interval 2: start=1617134, end=1631834, segment length=14700, t_offset=3234.2680
# Processing segment of length 14700 with t_offset=3234.2680
# Preparing signal segment, original length: 14700
# Signal segment length after padding: 14750
# STFT raw output: len(f) = 76 len(t) = 147 Zxx shape = (76, 147)
# STFT after normalization: len(t) = 147
# Interval processed: new t[0]=3234.418, last_t=3263.6180
# Interval 2: expected bins=147.0, actual bins=147, diff=0.0
# Processing interval 3: start=1631878, end=1643678, segment length=11800, t_offset=3263.7560
# Processing segment of length 11800 with t_offset=3263.7560
# Preparing signal segment, original length: 11800
# Signal segment length after padding: 11850
# STFT raw output: len(f) = 76 len(t) = 118 Zxx shape = (76, 118)
# STFT after normalization: len(t) = 118
# Interval processed: new t[0]=3263.906, last_t=3287.3060
# Interval 3: expected bins=118.0, actual bins=118, diff=0.0
# Processing interval 4: start=1643679, end=1645379, segment length=1700, t_offset=3287.3580
# Processing segment of length 1700 with t_offset=3287.3580
# Preparing signal segment, original length: 1700
# Signal segment length after padding: 1750
# STFT raw output: len(f) = 76 len(t) = 17 Zxx shape = (76, 17)
# STFT after normalization: len(t) = 17
# Interval processed: new t[0]=3287.5080000000003, last_t=3290.7080
# Interval 4: expected bins=17.0, actual bins=17, diff=0.0
# Processing interval 5: start=1645381, end=1649881, segment length=4500, t_offset=3290.7620
# Processing segment of length 4500 with t_offset=3290.7620
# Preparing signal segment, original length: 4500
# Signal segment length after padding: 4550
# STFT raw output: len(f) = 76 len(t) = 45 Zxx shape = (76, 45)
# STFT after normalization: len(t) = 45
# Interval processed: new t[0]=3290.9120000000003, last_t=3299.7120
# Interval 5: expected bins=45.0, actual bins=45, diff=0.0
# Processing interval 6: start=1649882, end=1650082, segment length=200, t_offset=3299.7640
# Processing segment of length 200 with t_offset=3299.7640
# Preparing signal segment, original length: 200
# Signal segment length after padding: 250
# STFT raw output: len(f) = 76 len(t) = 2 Zxx shape = (76, 2)
# STFT after normalization: len(t) = 2
# Interval processed: new t[0]=3299.914, last_t=3300.1140
# Interval 6: expected bins=2.0, actual bins=2, diff=0.0
# Processing interval 7: start=1650083, end=1659283, segment length=9200, t_offset=3300.1660
# Processing segment of length 9200 with t_offset=3300.1660
# Preparing signal segment, original length: 9200
# Signal segment length after padding: 9250
# STFT raw output: len(f) = 76 len(t) = 92 Zxx shape = (76, 92)
# STFT after normalization: len(t) = 92
# Interval processed: new t[0]=3300.3160000000003, last_t=3318.5160
# Interval 7: expected bins=92.0, actual bins=92, diff=0.0
# Processing interval 8: start=1659284, end=1663925, segment length=4641, t_offset=3318.5680
# Processing segment of length 4641 with t_offset=3318.5680
# Preparing signal segment, original length: 4641
# Signal segment length after padding: 4691
# STFT raw output: len(f) = 76 len(t) = 47 Zxx shape = (76, 47)
# STFT after normalization: len(t) = 47
# Interval processed: new t[0]=3318.7180000000003, last_t=3327.9180
# Interval 8: expected bins=46.41, actual bins=47, diff=0.5900000000000034
# 22,-0.0660000000002583
# Converted intervals to samples:
#        label    start      end
# 0  COUNTDOWN  1663926  1669143
# 1      OTHER  1669144  1670393
# 2       WORD  1670394  1684987
# 3      OTHER  1684988  1684995
# 4       PROB  1684996  1697904
# 5      OTHER  1697905  1700927
# 6   REC_WORD  1700928  1713504
# 7      OTHER  1713505  1716568
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 1663926, 'end': 1669143}, {'label': 'OTHER', 'start': 1669144, 'end': 1670393}, {'label': 'WORD', 'start': 1670394, 'end': 1684987}, {'label': 'OTHER', 'start': 1684988, 'end': 1684995}, {'label': 'PROB', 'start': 1684996, 'end': 1697904}, {'label': 'OTHER', 'start': 1697905, 'end': 1700927}, {'label': 'REC_WORD', 'start': 1700928, 'end': 1713504}, {'label': 'OTHER', 'start': 1713505, 'end': 1716568}]
# Processing interval 0: start=1663926, end=1669143, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 1669126, next interval new start: 1669127
# Processing interval 1: start=1669127, end=1670393, length=1266, modulo=66, division=12
# Interval 1 modulo > threshold, needed=34, next interval available=14593
# Extended interval 1 by 34 samples, new end: 1670427, next interval new start: 1670429
# Processing interval 2: start=1670429, end=1684987, length=14558, modulo=58, division=145
# Interval 2 modulo > threshold, needed=42, next interval available=7
# Merged interval 2 with next interval, new end: 1684995
# Processing interval 2: start=1670429, end=1684995, length=14566, modulo=66, division=145
# Interval 2 modulo > threshold, needed=34, next interval available=12908
# Extended interval 2 by 34 samples, new end: 1685029, next interval new start: 1685031
# Processing interval 3: start=1685031, end=1697904, length=12873, modulo=73, division=128
# Interval 3 modulo > threshold, needed=27, next interval available=3022
# Extended interval 3 by 27 samples, new end: 1697931, next interval new start: 1697933
# Processing interval 4: start=1697933, end=1700927, length=2994, modulo=94, division=29
# Interval 4 modulo > threshold, needed=6, next interval available=12576
# Extended interval 4 by 6 samples, new end: 1700933, next interval new start: 1700935
# Processing interval 5: start=1700935, end=1713504, length=12569, modulo=69, division=125
# Interval 5 modulo > threshold, needed=31, next interval available=3063
# Extended interval 5 by 31 samples, new end: 1713535, next interval new start: 1713537
# Processing interval 6: start=1713537, end=1716568, length=3031, modulo=31, division=30
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 1663926, 'end': 1669126}, {'label': 'OTHER', 'start': 1669127, 'end': 1670427}, {'label': 'WORD', 'start': 1670429, 'end': 1685029}, {'label': 'PROB', 'start': 1685031, 'end': 1697931}, {'label': 'OTHER', 'start': 1697933, 'end': 1700933}, {'label': 'REC_WORD', 'start': 1700935, 'end': 1713535}, {'label': 'OTHER', 'start': 1713537, 'end': 1716568}]
# Processing interval 0: start=1663926, end=1669126, segment length=5200, t_offset=3327.8520
# Processing segment of length 5200 with t_offset=3327.8520
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=3328.002, last_t=3338.2020
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=1669127, end=1670427, segment length=1300, t_offset=3338.2540
# Processing segment of length 1300 with t_offset=3338.2540
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=3338.404, last_t=3340.8040
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=1670429, end=1685029, segment length=14600, t_offset=3340.8580
# Processing segment of length 14600 with t_offset=3340.8580
# Preparing signal segment, original length: 14600
# Signal segment length after padding: 14650
# STFT raw output: len(f) = 76 len(t) = 146 Zxx shape = (76, 146)
# STFT after normalization: len(t) = 146
# Interval processed: new t[0]=3341.0080000000003, last_t=3370.0080
# Interval 2: expected bins=146.0, actual bins=146, diff=0.0
# Processing interval 3: start=1685031, end=1697931, segment length=12900, t_offset=3370.0620
# Processing segment of length 12900 with t_offset=3370.0620
# Preparing signal segment, original length: 12900
# Signal segment length after padding: 12950
# STFT raw output: len(f) = 76 len(t) = 129 Zxx shape = (76, 129)
# STFT after normalization: len(t) = 129
# Interval processed: new t[0]=3370.212, last_t=3395.8120
# Interval 3: expected bins=129.0, actual bins=129, diff=0.0
# Processing interval 4: start=1697933, end=1700933, segment length=3000, t_offset=3395.8660
# Processing segment of length 3000 with t_offset=3395.8660
# Preparing signal segment, original length: 3000
# Signal segment length after padding: 3050
# STFT raw output: len(f) = 76 len(t) = 30 Zxx shape = (76, 30)
# STFT after normalization: len(t) = 30
# Interval processed: new t[0]=3396.016, last_t=3401.8160
# Interval 4: expected bins=30.0, actual bins=30, diff=0.0
# Processing interval 5: start=1700935, end=1713535, segment length=12600, t_offset=3401.8700
# Processing segment of length 12600 with t_offset=3401.8700
# Preparing signal segment, original length: 12600
# Signal segment length after padding: 12650
# STFT raw output: len(f) = 76 len(t) = 126 Zxx shape = (76, 126)
# STFT after normalization: len(t) = 126
# Interval processed: new t[0]=3402.02, last_t=3427.0200
# Interval 5: expected bins=126.0, actual bins=126, diff=0.0
# Processing interval 6: start=1713537, end=1716568, segment length=3031, t_offset=3427.0740
# Processing segment of length 3031 with t_offset=3427.0740
# Preparing signal segment, original length: 3031
# Signal segment length after padding: 3081
# STFT raw output: len(f) = 76 len(t) = 31 Zxx shape = (76, 31)
# STFT after normalization: len(t) = 31
# Interval processed: new t[0]=3427.224, last_t=3433.2240
# Interval 6: expected bins=30.31, actual bins=31, diff=0.6900000000000013
# 23,-0.08599999999978536
# Converted intervals to samples:
#        label    start      end
# 0  COUNTDOWN  1716569  1721786
# 1      OTHER  1721787  1723069
# 2       WORD  1723070  1737572
# 3      OTHER  1737573  1737581
# 4       PROB  1737582  1750320
# 5      OTHER  1750321  1752978
# 6   REC_WORD  1752979  1764129
# 7      OTHER  1764130  1787515
# Original intervals_samples: [{'label': 'COUNTDOWN', 'start': 1716569, 'end': 1721786}, {'label': 'OTHER', 'start': 1721787, 'end': 1723069}, {'label': 'WORD', 'start': 1723070, 'end': 1737572}, {'label': 'OTHER', 'start': 1737573, 'end': 1737581}, {'label': 'PROB', 'start': 1737582, 'end': 1750320}, {'label': 'OTHER', 'start': 1750321, 'end': 1752978}, {'label': 'REC_WORD', 'start': 1752979, 'end': 1764129}, {'label': 'OTHER', 'start': 1764130, 'end': 1787515}]
# Processing interval 0: start=1716569, end=1721786, length=5217, modulo=17, division=52
# Adjusted interval 0 with modulo 17, new end: 1721769, next interval new start: 1721770
# Processing interval 1: start=1721770, end=1723069, length=1299, modulo=99, division=12
# Interval 1 modulo > threshold, needed=1, next interval available=14502
# Extended interval 1 by 1 samples, new end: 1723070, next interval new start: 1723072
# Processing interval 2: start=1723072, end=1737572, length=14500, modulo=0, division=145
# Discarding interval 2 as it has no valid length
# Processing interval 2: start=1737573, end=1737581, length=8, modulo=8, division=0
# Discarding interval 2 as it has no valid length
# Processing interval 2: start=1737582, end=1750320, length=12738, modulo=38, division=127
# Adjusted interval 2 with modulo 38, new end: 1750282, next interval new start: 1750283
# Processing interval 3: start=1750283, end=1752978, length=2695, modulo=95, division=26
# Interval 3 modulo > threshold, needed=5, next interval available=11150
# Extended interval 3 by 5 samples, new end: 1752983, next interval new start: 1752985
# Processing interval 4: start=1752985, end=1764129, length=11144, modulo=44, division=111
# Adjusted interval 4 with modulo 44, new end: 1764085, next interval new start: 1764086
# Processing interval 5: start=1764086, end=1787515, length=23429, modulo=29, division=234
# Processed intervals_samples: [{'label': 'COUNTDOWN', 'start': 1716569, 'end': 1721769}, {'label': 'OTHER', 'start': 1721770, 'end': 1723070}, {'label': 'PROB', 'start': 1737582, 'end': 1750282}, {'label': 'OTHER', 'start': 1750283, 'end': 1752983}, {'label': 'REC_WORD', 'start': 1752985, 'end': 1764085}, {'label': 'OTHER', 'start': 1764086, 'end': 1787515}]
# Processing interval 0: start=1716569, end=1721769, segment length=5200, t_offset=3433.1380
# Processing segment of length 5200 with t_offset=3433.1380
# Preparing signal segment, original length: 5200
# Signal segment length after padding: 5250
# STFT raw output: len(f) = 76 len(t) = 52 Zxx shape = (76, 52)
# STFT after normalization: len(t) = 52
# Interval processed: new t[0]=3433.288, last_t=3443.4880
# Interval 0: expected bins=52.0, actual bins=52, diff=0.0
# Processing interval 1: start=1721770, end=1723070, segment length=1300, t_offset=3443.5400
# Processing segment of length 1300 with t_offset=3443.5400
# Preparing signal segment, original length: 1300
# Signal segment length after padding: 1350
# STFT raw output: len(f) = 76 len(t) = 13 Zxx shape = (76, 13)
# STFT after normalization: len(t) = 13
# Interval processed: new t[0]=3443.69, last_t=3446.0900
# Interval 1: expected bins=13.0, actual bins=13, diff=0.0
# Processing interval 2: start=1737582, end=1750282, segment length=12700, t_offset=3475.1640
# Processing segment of length 12700 with t_offset=3475.1640
# Preparing signal segment, original length: 12700
# Signal segment length after padding: 12750
# STFT raw output: len(f) = 76 len(t) = 127 Zxx shape = (76, 127)
# STFT after normalization: len(t) = 127
# Interval processed: new t[0]=3475.3140000000003, last_t=3500.5140
# Interval 2: expected bins=127.0, actual bins=127, diff=0.0
# Processing interval 3: start=1750283, end=1752983, segment length=2700, t_offset=3500.5660
# Processing segment of length 2700 with t_offset=3500.5660
# Preparing signal segment, original length: 2700
# Signal segment length after padding: 2750
# STFT raw output: len(f) = 76 len(t) = 27 Zxx shape = (76, 27)
# STFT after normalization: len(t) = 27
# Interval processed: new t[0]=3500.716, last_t=3505.9160
# Interval 3: expected bins=27.0, actual bins=27, diff=0.0
# Processing interval 4: start=1752985, end=1764085, segment length=11100, t_offset=3505.9700
# Processing segment of length 11100 with t_offset=3505.9700
# Preparing signal segment, original length: 11100
# Signal segment length after padding: 11150
# STFT raw output: len(f) = 76 len(t) = 111 Zxx shape = (76, 111)
# STFT after normalization: len(t) = 111
# Interval processed: new t[0]=3506.12, last_t=3528.1200
# Interval 4: expected bins=111.0, actual bins=111, diff=0.0
# Processing interval 5: start=1764086, end=1787515, segment length=23429, t_offset=3528.1720
# Processing segment of length 23429 with t_offset=3528.1720
# Preparing signal segment, original length: 23429
# Signal segment length after padding: 23479
# STFT raw output: len(f) = 76 len(t) = 235 Zxx shape = (76, 235)
# STFT after normalization: len(t) = 235
# Interval processed: new t[0]=3528.322, last_t=3575.1220
# Interval 5: expected bins=234.29, actual bins=235, diff=0.710000000000008
# 24,-0.08999999999969077
# итого: -1.0800000000002683 из 3374.818 секунд исходной записи.

# %%
# # Чтение интервалов
# # activities, intervals = read_intervals_from_csv(csv_file_path)
# activities, intervals, activity_type = extract_intervals(tsv_file_path)
# print(f"Размерность intervals:{len(intervals)} на {len(intervals[0])}; Размерность activity_type:{len(activity_type)} на 1; Размерность activities:{len(activities)} на 1")

# # 6. Выбор одного случайного электродного канала (один рандомный электрод)
# num_electrodes = 1
# num_channels = random.sample(range(72), num_electrodes)

# %%
# # 5. Фильтрация интервалов по длительности (минимум 400 сэмплов)
# filtered_idx = []
# for i, d in enumerate(intervals):
#     if (d[1] - d[0]) * SamplingFrequency >= 400:
#         filtered_idx.append(i)
# threshold_intervals = [intervals[i] for i in filtered_idx]
# threshold_activities = [activities[i] for i in filtered_idx]
# threshold_activity_type = [activity_type[i] for i in filtered_idx]

# %%
# all_models = []
# all_intervals = []
# for trial_idx, (start, end) in enumerate(trials):
#     try:
#         filtered_int_index = []
#         new_intervals = []
#         for i, intr in enumerate(intervals):
#             if return_state(intr[0], intr[1], start, end) == "11":
#                 filtered_int_index.append(i)
#                 new_intervals.append((intr[0], intr[1]))
#             elif return_state(intr[0], intr[1], start, end) == "10":
#                 filtered_int_index.append(i)
#                 new_intervals.append((intr[0], end))
#             elif return_state(intr[0], intr[1], start, end) == "01":
#                 filtered_int_index.append(i)
#                 new_intervals.append((start, intr[1]))

#         # Теперь filtered_digit содержит только те позиции, которые удовлетворяют условию
#         fit_intervals = new_intervals
#         fit_activities = [activities[i] for i in filtered_int_index]
#         fit_activity_type = [activity_type[i] for i in filtered_int_index]
#         stft_data_array, f, t = generate_stft_data(recording, chosen_rec, (start, end), SamplingFrequency)
#         with torch.no_grad():
#             model_outputs = get_model_outputs(stft_data_array, model)
#             all_models.append(model_outputs[num_channels[0]].cpu().numpy())
#             torch.cuda.empty_cache()
#         all_intervals.append(sovu_na_globus(fit_intervals, t, start, fit_activity_type))
#     except RuntimeError as e:
#         print(f'| WARNING: ran out of memory, retrying batch \n {e}')
#         torch.cuda.empty_cache()

# %%
# pca = PCA(n_components=2).fit(all_models[0])
# fig, ax = plt.subplots(1, 1, figsize=(12, 12))
# plt.subplots_adjust(right=0.90)  # Оставляем 15% ширины для легенды

# # Цвета для activity_type
# unique_activity_types = list(set(activity_type))
# colors = sns.husl_palette(len(unique_activity_types))
# activity_color_map = {atype: color for atype, color in zip(unique_activity_types, colors)}


# for averaged_data, activity_t in zip(all_models, all_intervals):
#     proj = pca.transform(averaged_data)
#     col = [activity_color_map[atype] for atype in activity_t]
#     ax.minorticks_on()
#     ax.grid(True, which='minor', linestyle=':', linewidth=0.9, color='gray', alpha=0.5)
#     ax.grid(True, which='major', linestyle='-', linewidth=0.5, color='gray', alpha=0.7)
#     ax.scatter(proj[:, 0], proj[:, 1], color=col, s=10, edgecolor="k", alpha = 0.5)


# # Создаем легенду с элементами для всех типов активности
# handles = [
#     plt.Line2D([0], [0], marker='o', color='w', label=atype,
#                 markerfacecolor=color, markersize=10)
#     for atype, color in activity_color_map.items()
# ]

# # Проверяем, что handles не пустой
# if handles:
#     fig.legend(
#         handles=handles,
#         title="Activity Type",
#         loc="center left",             # Привязываем к левому краю области для легенды
#         bbox_to_anchor=(0.90, 0.5),     # Центрируем вертикально
#         borderaxespad=0.0,             # Убираем лишние отступы
#         frameon=False                  # Убираем рамку вокруг легенды
#     )

# plt.show()

# %%
# pca = PCA(n_components=2).fit(all_models[0])
# fig, axs = plt.subplots(5, 5, figsize=(12, 12))
# plt.subplots_adjust(right=0.90)  # Оставляем 15% ширины для легенды

# # Цвета для activity_type
# unique_activity_types = list(set(activity_type))
# colors = sns.husl_palette(len(unique_activity_types))
# activity_color_map = {atype: color for atype, color in zip(unique_activity_types, colors)}

# act_alignment = {}

# for ax, atype in zip(axs.flatten(), unique_activity_types):
#     ax.set_title(atype)
#     ax.set_xlim(-23, 20)
#     ax.set_ylim(-22, 19)

#     ax.minorticks_on()
#     ax.grid(True, which='minor', linestyle=':', linewidth=0.9, color='gray', alpha=0.5)
#     ax.grid(True, which='major', linestyle='-', linewidth=0.5, color='gray', alpha=0.7)

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)
#     ax.spines['bottom'].set_visible(False)
#     ax.spines['left'].set_visible(False)

#     ax.tick_params(axis='both', which='both', length=0)
#     ax.set_xticklabels([])
#     ax.set_yticklabels([])

#     act_alignment[atype] = ax

# points_by_activity = {atype: [] for atype in unique_activity_types}
# for averaged_data, activity_t in zip(all_models, all_intervals):
#     proj = pca.transform(averaged_data)
#     for point, atype in zip(proj, activity_t):
#         points_by_activity[atype].append(point)

# for atype, ax in act_alignment.items():
#     pts = np.array(points_by_activity[atype])
#     if pts.size > 0:
#         ax.scatter(pts[:, 0], pts[:, 1], s=10, color=activity_color_map[atype],
#                    edgecolor="k", alpha=0.25)

# # Создаем легенду с элементами для всех типов активности
# handles = [
#     plt.Line2D([0], [0], marker='o', color='w', label=atype,
#                 markerfacecolor=color, markersize=10)
#     for atype, color in activity_color_map.items()
# ]

# # Проверяем, что handles не пустой
# if handles:
#     fig.legend(
#         handles=handles,
#         title="Activity Type",
#         loc="center left",             # Привязываем к левому краю области для легенды
#         bbox_to_anchor=(0.90, 0.5),     # Центрируем вертикально
#         borderaxespad=0.0,             # Убираем лишние отступы
#         frameon=False                  # Убираем рамку вокруг легенды
#     )

# plt.show()
